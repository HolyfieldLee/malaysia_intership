# %% [markdown]
# # Offer

# %%
import pandas as pd
import re
import numpy as np

def preprocess_offer(file_path):
    # 엑셀 파일을 DataFrame으로 불러옵니다.
    offer = pd.read_excel(file_path)

    offer.drop(columns=['Unnamed: 0'], inplace=True)
    offer.drop(offer.index[1157], axis=0, inplace=True)
    offer['Capacity'] = offer['Capacity'].astype(int)
    offer['Min Per Session'] = offer['Min Per Session'].astype(int)

    offer['Session'] = offer['Session'].str.upper()
    offer['Lecturer'] = offer['Lecturer'].str.upper()
    offer['CourseCode'] = offer['CourseCode'].str.upper()
    offer['FacultyCode'] = offer['FacultyCode'].str.upper()

    offer['Session'] = offer['Session'].str.replace(r'\(S\)', '', regex=True)

    # "COMBINED TO /"를 복사하여 error 테이블에 저장. 이후 원본 데이터에서 삭제.
    mask = offer['Session'].str.contains("COMBINED TO /", na=False)

    # error 데이터프레임에 해당 행들을 복사하여 저장합니다.
    error = offer[mask].copy()

    # 원본 offer 데이터프레임에서 해당 행들을 삭제합니다.
    offer.drop(offer[mask].index, inplace=True)

    #"GROUP A", "GROUP B", "GROUP C" 등 해당하는 행을 찾고, Session 값을 "LECTURE"로 변경
    offer.loc[offer['Session'].str.contains(r'^GROUP\s+[A-Z]$', na=False), 'Session'] = 'LECTURE'

    group_cols = ['CourseCode', 'FacultyCode', 'Session', 'Capacity', 'Min Per Session', 'Lecturer']

    # 그룹별로 중복된 행을 처리합니다.
    for _, group in offer.groupby(group_cols):
        if len(group) > 1:  # 중복 그룹인 경우
            # 원래 Session 값을 앞뒤 공백 제거 후 사용합니다.
            orig_session = group.iloc[0]['Session'].strip()
            # Session 값이 숫자로 끝나는지 검사 (예: "TUTORIAL 1")
            m = re.search(r'^(.*?)(\d+)$', orig_session)
            if m:
                base = m.group(1).strip()  # 문자 부분 (예: "TUTORIAL")
                start_num = int(m.group(2))  # 기존에 붙은 숫자 (예: 1)
            else:
                base = orig_session
                start_num = 1

            # 그룹 내 각 행에 대해 순차적으로 번호를 붙여 Session 값을 변경합니다.
            for offset, idx in enumerate(group.index):
                new_session = f"{base} {start_num + offset}"
                offer.at[idx, 'Session'] = new_session

    # (초기 전제: offer DataFrame과 error DataFrame이 존재함; error가 없으면 빈 DataFrame 생성)
    if 'error' not in globals():
        error = pd.DataFrame()

    ### Step 1. offer에서 "COMBINED TO" 행 추출 → child_class로 저장, offer에서는 제거
    child_class = offer[offer['Session'].str.contains('COMBINED TO', na=False)].copy()
    offer.drop(child_class.index, inplace=True)

    ### Step 2. child_class의 Session 열에서 과목코드 추출
    child_class['extracted_code'] = child_class['Session'].str.extract(r'COMBINED TO\s+([A-Z0-9]+)', expand=False)

    ### Step 3. child_class 내에서 오류 및 정상/후손 분리

    # (A) "자기 자신 참조" 조건: 추출한 코드가 해당 행의 CourseCode와 같으면 → 오류
    self_ref = child_class['extracted_code'] == child_class['CourseCode']

    # (B) 정상(child) 조건: 자기 자신 참조가 아니고, 추출한 코드가 offer의 CourseCode에 존재하는 경우
    valid_child_mask = (~self_ref) & (child_class['extracted_code'].isin(offer['CourseCode']))

    # (C) 후손(grandchild) 후보: 자기 자신 참조가 아니고, 추출한 코드가 offer에는 없지만, child_class의 CourseCode에는 존재하는 경우  
    #     (즉, 부모(대상 CourseCode)가 offer에 없으므로 자식끼리 연결되어 있음을 의미)
    valid_grand_mask = (~self_ref) & (~child_class['extracted_code'].isin(offer['CourseCode'])) & \
                        (child_class['extracted_code'].isin(child_class['CourseCode']))

    # (D) 오류 조건:  
    #     - 자기 자신 참조인 경우  
    #     - 또는 추출한 코드가 offer에도 child_class에도 존재하지 않는 경우
    error_mask = self_ref | ((~child_class['extracted_code'].isin(offer['CourseCode'])) & 
                               (~child_class['extracted_code'].isin(child_class['CourseCode'])))

    # child_class 오류 처리: 추출
    child_error = child_class[error_mask].copy()

    # 정상 child_class (valid_child) 추출
    valid_child = child_class[valid_child_mask].copy()

    # 후보 후손(grandchild) 추출
    candidate_grand = child_class[valid_grand_mask].copy()

    ### Step 4. grand_child_class 내에서 추가 오류 처리
    # 오류 조건 (grandchild): 자기 자신 참조 → 오류
    grand_self_ref = candidate_grand['extracted_code'] == candidate_grand['CourseCode']
    error_grand = candidate_grand[grand_self_ref].copy()

    # 최종 grand_child_class: 후보에서 자기 자신 참조 오류 제거
    grand_child_class = candidate_grand[~grand_self_ref].copy()

    # 최종 error: 기존 child 오류와 후손에서 발생한 오류를 모두 누적
    error_df = pd.concat([child_error, error_grand], ignore_index=True)
    error = pd.concat([error, error_df], ignore_index=True)

    ### 최종 정상 데이터
    # child_class는 valid_child로 업데이트 (offer의 부모가 존재하는 경우)
    child_class = valid_child.copy()
    # grand_child_class는 위에서 구한 대로

    # error DataFrame이 없으면 빈 DataFrame 생성
    if 'error' not in globals():
        error = pd.DataFrame()

    ##############################################
    # 교차검증 1: child_class에서 자기 자신 참조하는 행 처리
    ##############################################
    child_self_ref_mask = (child_class['extracted_code'] == child_class['CourseCode'])
    child_self_ref_errors = child_class[child_self_ref_mask].copy()
    error = pd.concat([error, child_self_ref_errors], ignore_index=True)
    child_class = child_class[~child_self_ref_mask].copy()

    ##############################################
    # 교차검증 2: child_class에서 추출한 과목코드가 offer의 CourseCode에 없음(부모 없음)
    ##############################################
    child_missing_parent_mask = ~child_class['extracted_code'].isin(offer['CourseCode'])
    child_missing_parent_errors = child_class[child_missing_parent_mask].copy()
    error = pd.concat([error, child_missing_parent_errors], ignore_index=True)
    child_class = child_class[~child_missing_parent_mask].copy()

    ##############################################
    # 교차검증 3: offer에서 자기 자신 참조하는 행 처리
    # (offer에 COMBINED TO가 남아있다면 해당 행에 대해 extracted_code를 추출)
    ##############################################
    offer_combined_mask = offer['Session'].str.contains('COMBINED TO', na=False)
    if offer_combined_mask.any():
        offer.loc[offer_combined_mask, 'extracted_code'] = offer.loc[offer_combined_mask, 'Session'].str.extract(r'COMBINED TO\s+([A-Z0-9]+)', expand=False)
        offer_self_ref_mask = (offer['extracted_code'] == offer['CourseCode'])
        offer_self_ref_errors = offer[offer_self_ref_mask].copy()
        error = pd.concat([error, offer_self_ref_errors], ignore_index=True)
        offer.drop(offer[offer_self_ref_mask].index, inplace=True)

    ##############################################
    # 교차검증 4: grand_child_class에서 자기 자신 참조하는 행 처리
    ##############################################
    grand_self_ref_mask = (grand_child_class['extracted_code'] == grand_child_class['CourseCode'])
    grand_self_ref_errors = grand_child_class[grand_self_ref_mask].copy()
    error = pd.concat([error, grand_self_ref_errors], ignore_index=True)
    grand_child_class = grand_child_class[~grand_self_ref_mask].copy()

    ##############################################
    # 교차검증 5: grand_child_class에서 추출한 과목코드가 offer의 CourseCode에 없음(부모 없음)
    ##############################################
    grand_missing_parent_mask = ~grand_child_class['extracted_code'].isin(offer['CourseCode'])
    grand_missing_parent_errors = grand_child_class[grand_missing_parent_mask].copy()
    error = pd.concat([error, grand_missing_parent_errors], ignore_index=True)
    grand_child_class = grand_child_class[~grand_missing_parent_mask].copy()

    ##############################################
    # 교차검증 6: 부모(offer 또는 child_class)에서 드랍된 행과 연결된 자식(또는 손자) 행 처리
    # 드랍된 행들의 CourseCode를 모아서, 이 코드를 extracted_code로 사용하는 행이 있다면 error로 처리
    ##############################################
    # 지금까지 error에 추가된 행들의 CourseCode를 모읍니다.
    dropped_codes = set(error['CourseCode'].unique())

    # child_class에서 연결된 자식 행 검사
    child_linked_mask = child_class['extracted_code'].isin(dropped_codes)
    child_linked_errors = child_class[child_linked_mask].copy()
    error = pd.concat([error, child_linked_errors], ignore_index=True)
    child_class = child_class[~child_linked_mask].copy()

    # grand_child_class에서 연결된 손자 행 검사
    grand_linked_mask = grand_child_class['extracted_code'].isin(dropped_codes)
    grand_linked_errors = grand_child_class[grand_linked_mask].copy()
    error = pd.concat([error, grand_linked_errors], ignore_index=True)
    grand_child_class = grand_child_class[~grand_linked_mask].copy()

    # child_class의 각 행을 순회하며 조건에 맞는 offer 행의 Capacity에 child_class의 Capacity를 합산합니다.
    for idx, child_row in child_class.iterrows():
        # 조건: offer의 CourseCode, Min Per Session, Lecturer가 child_row의 extracted_code, Min Per Session, Lecturer와 일치
        mask = (
            (offer['CourseCode'] == child_row['extracted_code']) &
            (offer['Min Per Session'] == child_row['Min Per Session']) &
            (offer['Lecturer'] == child_row['Lecturer'])
        )
        # 일치하는 행이 있다면, offer의 Capacity에 child_row의 Capacity를 더함
        if mask.any():
            offer.loc[mask, 'Capacity'] += child_row['Capacity']

    # 기존 조건
    conditions = [
        offer['Session'].str.contains('LECTURE & TUTORIAL', na=False, case=False),
        offer['Session'].str.contains('TUTORIAL', na=False, case=False),
        offer['Session'].str.contains('LECTURE', na=False, case=False),
        offer['Session'].str.contains('LAB', na=False, case=False),
        offer['Session'].str.contains('PBL 1', na=False, case=False),
        offer['Session'].str.contains('HAND DRAWING|CAD DRAWING 2|CAD DRAWING 1', na=False, case=False),
        offer['Session'].str.contains('KITCHEN', na=False, case=False),
        offer['Session'].str.contains('OPTOM CLINIC|SOO - EXAM CLINIC', na=False, case=False)
    ]

    # 기존 선택지 + 새 선택지
    choices = [
        'GENERAL',
        'TUTORIAL',
        'LECTURE',
        'LAB',
        'PBL',
        'ART',
        'KITCHEN',
        'LECTURE'
    ]

    # 조건을 적용하여 'Category' 열 생성
    offer['Category'] = np.select(conditions, choices, default=np.nan)
    
    return offer

file_path = r"C:\Users\light\Desktop\CSD - Course Offer.xlsx"  # Windows 경로 예시
offer = preprocess_offer(file_path)

offer
# Out:
#      CourseCode FacultyCode               Session  Capacity  Min Per Session  \
# 6         AB443        SABE               LECTURE        25              180
# 7         AB516        SABE  LECTURE FATHER CLASS        50              450
# 8         AB533        SABE  LECTURE FATHER CLASS        40              180
# 10        AB618        SABE             LECTURE 2        20              240
# 11        AB618        SABE             LECTURE 1        20              210
# ...         ...         ...                   ...       ...              ...
# 1152      SP206      FOSSLA             LECTURE 1        20              180
# 1153      SP206      FOSSLA             LECTURE 2        20              180
# 1154      SP208      FOSSLA              LECTURE          5              120
# 1155      SP208      FOSSLA              LECTURE          5              180
# 1156      SP208      FOSSLA              LECTURE          5               60
#
#                                     Lecturer Category
# 6                        NURUL ANIDA MOHAMAD  LECTURE
# 7                             LIM KER CHWING  LECTURE
# 8     ASST. PROF. IDR BAIZURA HANIM BT BIDIN  LECTURE
# 10                       NURUL ANIDA MOHAMAD  LECTURE
# 11                       NURUL ANIDA MOHAMAD  LECTURE
# ...                                      ...      ...
# 1152             NURUL HIDAYAH BT MOHD SA'AT  LECTURE
# 1153             NURUL HIDAYAH BT MOHD SA'AT  LECTURE
# 1154                       ARMAN IMRAN ASHOK  LECTURE
# 1155                       ARMAN IMRAN ASHOK  LECTURE
# 1156                       ARMAN IMRAN ASHOK  LECTURE
#
# [808 rows x 7 columns]

# %%
import pandas as pd

# 엑셀 파일의 절대 경로 또는 주피터 노트북 기준 상대 경로를 지정합니다.
file_path = r"C:\Users\light\Desktop\CSD - Course Offer.xlsx"  # Windows 경로 예시

# 엑셀 파일을 DataFrame으로 불러옵니다.
offer = pd.read_excel(file_path)

offer.drop(columns=['Unnamed: 0'], inplace=True)
offer.drop(offer.index[1157], axis=0, inplace=True)
offer['Capacity'] = offer['Capacity'].astype(int)
offer['Min Per Session'] = offer['Min Per Session'].astype(int)

total_time = 134790

offer
# Out:
#      CourseCode FacultyCode                                  Session  \
# 0         AB243        SABE      Lecture Combined To BEI1083/Lecture
# 1         AB316        SABE      Lecture Combined To BEI2017/Lecture
# 2         AB343        SABE      Lecture Combined To BEI2033/Lecture
# 3         AB416        SABE  Lecture 1 Combined To BEI2067/Lecture 1
# 4         AB416        SABE  Lecture 2 Combined To BEI2067/Lecture 2
# ...         ...         ...                                      ...
# 1152      SP206      FOSSLA                              Lecture (S)
# 1153      SP206      FOSSLA                              Lecture (S)
# 1154      SP208      FOSSLA                              Lecture (S)
# 1155      SP208      FOSSLA                              Lecture (S)
# 1156      SP208      FOSSLA                              Lecture (S)
#
#       Capacity  Min Per Session                                Lecturer
# 0            5              180                     Nurul Anida Mohamad
# 1            5              450                      Dr. Wong Leong Yee
# 2            5              180                         Humanson Gimfil
# 3           10              210  Asst. Prof. IDr Baizura Hanim Bt Bidin
# 4           10              240  Asst. Prof. IDr Baizura Hanim Bt Bidin
# ...        ...              ...                                     ...
# 1152        20              180             Nurul Hidayah Bt Mohd Sa'at
# 1153        20              180             Nurul Hidayah Bt Mohd Sa'at
# 1154         5              120                       Arman Imran Ashok
# 1155         5              180                       Arman Imran Ashok
# 1156         5               60                       Arman Imran Ashok
#
# [1157 rows x 6 columns]

# %%
#전체 데이터를 대문자로 바꾸는 코드
offer['Session'] = offer['Session'].str.upper()
offer['Lecturer'] = offer['Lecturer'].str.upper()
offer['CourseCode'] = offer['CourseCode'].str.upper()
offer['FacultyCode'] = offer['FacultyCode'].str.upper()

offer
# Out:
#      CourseCode FacultyCode                                  Session  \
# 0         AB243        SABE      LECTURE COMBINED TO BEI1083/LECTURE
# 1         AB316        SABE      LECTURE COMBINED TO BEI2017/LECTURE
# 2         AB343        SABE      LECTURE COMBINED TO BEI2033/LECTURE
# 3         AB416        SABE  LECTURE 1 COMBINED TO BEI2067/LECTURE 1
# 4         AB416        SABE  LECTURE 2 COMBINED TO BEI2067/LECTURE 2
# ...         ...         ...                                      ...
# 1152      SP206      FOSSLA                              LECTURE (S)
# 1153      SP206      FOSSLA                              LECTURE (S)
# 1154      SP208      FOSSLA                              LECTURE (S)
# 1155      SP208      FOSSLA                              LECTURE (S)
# 1156      SP208      FOSSLA                              LECTURE (S)
#
#       Capacity  Min Per Session                                Lecturer
# 0            5              180                     NURUL ANIDA MOHAMAD
# 1            5              450                      DR. WONG LEONG YEE
# 2            5              180                         HUMANSON GIMFIL
# 3           10              210  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 4           10              240  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# ...        ...              ...                                     ...
# 1152        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1153        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1154         5              120                       ARMAN IMRAN ASHOK
# 1155         5              180                       ARMAN IMRAN ASHOK
# 1156         5               60                       ARMAN IMRAN ASHOK
#
# [1157 rows x 6 columns]

# %%
#전체 데이터에서 (s)를 삭제하는 코드
offer['Session'] = offer['Session'].str.replace(r'\(S\)', '', regex=True)
offer
# Out:
#      CourseCode FacultyCode                                  Session  \
# 0         AB243        SABE      LECTURE COMBINED TO BEI1083/LECTURE
# 1         AB316        SABE      LECTURE COMBINED TO BEI2017/LECTURE
# 2         AB343        SABE      LECTURE COMBINED TO BEI2033/LECTURE
# 3         AB416        SABE  LECTURE 1 COMBINED TO BEI2067/LECTURE 1
# 4         AB416        SABE  LECTURE 2 COMBINED TO BEI2067/LECTURE 2
# ...         ...         ...                                      ...
# 1152      SP206      FOSSLA                                 LECTURE
# 1153      SP206      FOSSLA                                 LECTURE
# 1154      SP208      FOSSLA                                 LECTURE
# 1155      SP208      FOSSLA                                 LECTURE
# 1156      SP208      FOSSLA                                 LECTURE
#
#       Capacity  Min Per Session                                Lecturer
# 0            5              180                     NURUL ANIDA MOHAMAD
# 1            5              450                      DR. WONG LEONG YEE
# 2            5              180                         HUMANSON GIMFIL
# 3           10              210  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 4           10              240  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# ...        ...              ...                                     ...
# 1152        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1153        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1154         5              120                       ARMAN IMRAN ASHOK
# 1155         5              180                       ARMAN IMRAN ASHOK
# 1156         5               60                       ARMAN IMRAN ASHOK
#
# [1157 rows x 6 columns]

# %%
# "COMBINED TO /"를 복사하여 error 테이블에 저장. 이후 원본 데이터에서 삭제.
mask = offer['Session'].str.contains("COMBINED TO /", na=False)

# error 데이터프레임에 해당 행들을 복사하여 저장합니다.
error = offer[mask].copy()

# 원본 offer 데이터프레임에서 해당 행들을 삭제합니다.
offer.drop(offer[mask].index, inplace=True)

error
# Out:
#      CourseCode FacultyCode         Session  Capacity  Min Per Session  \
# 80      BAC1014         FAS   COMBINED TO /         5              180
# 162     BBA1134         FBM   COMBINED TO /        20              180
# 863       EA103       FETBE   COMBINED TO /         2               60
# 864       EA103       FETBE   COMBINED TO /         2               60
# 1050      MS201         FAS   COMBINED TO /        10              120
# 1051      MS201         FAS   COMBINED TO /        10               60
# 1052      MS201         FAS   COMBINED TO /        10               60
# 1053      MS201         FAS   COMBINED TO /        10              120
#
#      Lecturer
# 80        NaN
# 162       NaN
# 863       NaN
# 864       NaN
# 1050      NaN
# 1051      NaN
# 1052      NaN
# 1053      NaN

# %%
offer
# Out:
#      CourseCode FacultyCode                                  Session  \
# 0         AB243        SABE      LECTURE COMBINED TO BEI1083/LECTURE
# 1         AB316        SABE      LECTURE COMBINED TO BEI2017/LECTURE
# 2         AB343        SABE      LECTURE COMBINED TO BEI2033/LECTURE
# 3         AB416        SABE  LECTURE 1 COMBINED TO BEI2067/LECTURE 1
# 4         AB416        SABE  LECTURE 2 COMBINED TO BEI2067/LECTURE 2
# ...         ...         ...                                      ...
# 1152      SP206      FOSSLA                                 LECTURE
# 1153      SP206      FOSSLA                                 LECTURE
# 1154      SP208      FOSSLA                                 LECTURE
# 1155      SP208      FOSSLA                                 LECTURE
# 1156      SP208      FOSSLA                                 LECTURE
#
#       Capacity  Min Per Session                                Lecturer
# 0            5              180                     NURUL ANIDA MOHAMAD
# 1            5              450                      DR. WONG LEONG YEE
# 2            5              180                         HUMANSON GIMFIL
# 3           10              210  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 4           10              240  ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# ...        ...              ...                                     ...
# 1152        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1153        20              180             NURUL HIDAYAH BT MOHD SA'AT
# 1154         5              120                       ARMAN IMRAN ASHOK
# 1155         5              180                       ARMAN IMRAN ASHOK
# 1156         5               60                       ARMAN IMRAN ASHOK
#
# [1149 rows x 6 columns]

# %%
#"GROUP A", "GROUP B", "GROUP C" 등 해당하는 행을 찾고, Session 값을 "LECTURE"로 변경
offer.loc[offer['Session'].str.contains(r'^GROUP\s+[A-Z]$', na=False), 'Session'] = 'LECTURE'

# 결과 확인
offer.loc[[1027]]
# Out:
#      CourseCode FacultyCode  Session  Capacity  Min Per Session  \
# 1027    MPU3221      FOSSLA  LECTURE       300               60
#
#                          Lecturer
# 1027  DR. SITI NUR AAFIFAH HASHIM

# %%
#중복된 행들에 숫자를 붙여서 다른 수업임을 명시. 이때 이미 숫자가 붙어있는상태로 중복이라면, 해당 숫자를 기준으로 중복을 처리함.
import re

group_cols = ['CourseCode', 'FacultyCode', 'Session', 'Capacity', 'Min Per Session', 'Lecturer']

# 그룹별로 중복된 행을 처리합니다.
for _, group in offer.groupby(group_cols):
    if len(group) > 1:  # 중복 그룹인 경우
        # 원래 Session 값을 앞뒤 공백 제거 후 사용합니다.
        orig_session = group.iloc[0]['Session'].strip()
        # Session 값이 숫자로 끝나는지 검사 (예: "TUTORIAL 1")
        m = re.search(r'^(.*?)(\d+)$', orig_session)
        if m:
            base = m.group(1).strip()  # 문자 부분 (예: "TUTORIAL")
            start_num = int(m.group(2))  # 기존에 붙은 숫자 (예: 1)
        else:
            base = orig_session
            start_num = 1
        
        # 그룹 내 각 행에 대해 순차적으로 번호를 붙여 Session 값을 변경합니다.
        for offset, idx in enumerate(group.index):
            new_session = f"{base} {start_num + offset}"
            offer.at[idx, 'Session'] = new_session

offer.loc[[166]]
# Out:
#     CourseCode FacultyCode     Session  Capacity  Min Per Session  \
# 166    BBA1703         FBM  TUTORIAL 2        40               60
#
#                           Lecturer
# 166  BRAHAM RAHUL RAM A/L JAMNADAS

# %%
import pandas as pd

# (초기 전제: offer DataFrame과 error DataFrame이 존재함; error가 없으면 빈 DataFrame 생성)
if 'error' not in globals():
    error = pd.DataFrame()

### Step 1. offer에서 "COMBINED TO" 행 추출 → child_class로 저장, offer에서는 제거
child_class = offer[offer['Session'].str.contains('COMBINED TO', na=False)].copy()
offer.drop(child_class.index, inplace=True)

### Step 2. child_class의 Session 열에서 과목코드 추출
child_class['extracted_code'] = child_class['Session'].str.extract(r'COMBINED TO\s+([A-Z0-9]+)', expand=False)

### Step 3. child_class 내에서 오류 및 정상/후손 분리

# (A) "자기 자신 참조" 조건: 추출한 코드가 해당 행의 CourseCode와 같으면 → 오류
self_ref = child_class['extracted_code'] == child_class['CourseCode']

# (B) 정상(child) 조건: 자기 자신 참조가 아니고, 추출한 코드가 offer의 CourseCode에 존재하는 경우
valid_child_mask = (~self_ref) & (child_class['extracted_code'].isin(offer['CourseCode']))

# (C) 후손(grandchild) 후보: 자기 자신 참조가 아니고, 추출한 코드가 offer에는 없지만, child_class의 CourseCode에는 존재하는 경우  
#     (즉, 부모(대상 CourseCode)가 offer에 없으므로 자식끼리 연결되어 있음을 의미)
valid_grand_mask = (~self_ref) & (~child_class['extracted_code'].isin(offer['CourseCode'])) & \
                    (child_class['extracted_code'].isin(child_class['CourseCode']))

# (D) 오류 조건:  
#     - 자기 자신 참조인 경우  
#     - 또는 추출한 코드가 offer에도 child_class에도 존재하지 않는 경우
error_mask = self_ref | ((~child_class['extracted_code'].isin(offer['CourseCode'])) & 
                           (~child_class['extracted_code'].isin(child_class['CourseCode'])))

# child_class 오류 처리: 추출
child_error = child_class[error_mask].copy()

# 정상 child_class (valid_child) 추출
valid_child = child_class[valid_child_mask].copy()

# 후보 후손(grandchild) 추출
candidate_grand = child_class[valid_grand_mask].copy()

### Step 4. grand_child_class 내에서 추가 오류 처리
# 오류 조건 (grandchild): 자기 자신 참조 → 오류
grand_self_ref = candidate_grand['extracted_code'] == candidate_grand['CourseCode']
error_grand = candidate_grand[grand_self_ref].copy()

# 최종 grand_child_class: 후보에서 자기 자신 참조 오류 제거
grand_child_class = candidate_grand[~grand_self_ref].copy()

# 최종 error: 기존 child 오류와 후손에서 발생한 오류를 모두 누적
error_df = pd.concat([child_error, error_grand], ignore_index=True)
error = pd.concat([error, error_df], ignore_index=True)

### 최종 정상 데이터
# child_class는 valid_child로 업데이트 (offer의 부모가 존재하는 경우)
child_class = valid_child.copy()
# grand_child_class는 위에서 구한 대로

# %%
import pandas as pd

# error DataFrame이 없으면 빈 DataFrame 생성
if 'error' not in globals():
    error = pd.DataFrame()

##############################################
# 교차검증 1: child_class에서 자기 자신 참조하는 행 처리
##############################################
child_self_ref_mask = (child_class['extracted_code'] == child_class['CourseCode'])
child_self_ref_errors = child_class[child_self_ref_mask].copy()
error = pd.concat([error, child_self_ref_errors], ignore_index=True)
child_class = child_class[~child_self_ref_mask].copy()

##############################################
# 교차검증 2: child_class에서 추출한 과목코드가 offer의 CourseCode에 없음(부모 없음)
##############################################
child_missing_parent_mask = ~child_class['extracted_code'].isin(offer['CourseCode'])
child_missing_parent_errors = child_class[child_missing_parent_mask].copy()
error = pd.concat([error, child_missing_parent_errors], ignore_index=True)
child_class = child_class[~child_missing_parent_mask].copy()

##############################################
# 교차검증 3: offer에서 자기 자신 참조하는 행 처리
# (offer에 COMBINED TO가 남아있다면 해당 행에 대해 extracted_code를 추출)
##############################################
offer_combined_mask = offer['Session'].str.contains('COMBINED TO', na=False)
if offer_combined_mask.any():
    offer.loc[offer_combined_mask, 'extracted_code'] = offer.loc[offer_combined_mask, 'Session'].str.extract(r'COMBINED TO\s+([A-Z0-9]+)', expand=False)
    offer_self_ref_mask = (offer['extracted_code'] == offer['CourseCode'])
    offer_self_ref_errors = offer[offer_self_ref_mask].copy()
    error = pd.concat([error, offer_self_ref_errors], ignore_index=True)
    offer.drop(offer[offer_self_ref_mask].index, inplace=True)

##############################################
# 교차검증 4: grand_child_class에서 자기 자신 참조하는 행 처리
##############################################
grand_self_ref_mask = (grand_child_class['extracted_code'] == grand_child_class['CourseCode'])
grand_self_ref_errors = grand_child_class[grand_self_ref_mask].copy()
error = pd.concat([error, grand_self_ref_errors], ignore_index=True)
grand_child_class = grand_child_class[~grand_self_ref_mask].copy()

##############################################
# 교차검증 5: grand_child_class에서 추출한 과목코드가 offer의 CourseCode에 없음(부모 없음)
##############################################
grand_missing_parent_mask = ~grand_child_class['extracted_code'].isin(offer['CourseCode'])
grand_missing_parent_errors = grand_child_class[grand_missing_parent_mask].copy()
error = pd.concat([error, grand_missing_parent_errors], ignore_index=True)
grand_child_class = grand_child_class[~grand_missing_parent_mask].copy()

##############################################
# 교차검증 6: 부모(offer 또는 child_class)에서 드랍된 행과 연결된 자식(또는 손자) 행 처리
# 드랍된 행들의 CourseCode를 모아서, 이 코드를 extracted_code로 사용하는 행이 있다면 error로 처리
##############################################
# 지금까지 error에 추가된 행들의 CourseCode를 모읍니다.
dropped_codes = set(error['CourseCode'].unique())

# child_class에서 연결된 자식 행 검사
child_linked_mask = child_class['extracted_code'].isin(dropped_codes)
child_linked_errors = child_class[child_linked_mask].copy()
error = pd.concat([error, child_linked_errors], ignore_index=True)
child_class = child_class[~child_linked_mask].copy()

# grand_child_class에서 연결된 손자 행 검사
grand_linked_mask = grand_child_class['extracted_code'].isin(dropped_codes)
grand_linked_errors = grand_child_class[grand_linked_mask].copy()
error = pd.concat([error, grand_linked_errors], ignore_index=True)
grand_child_class = grand_child_class[~grand_linked_mask].copy()

##############################################
# 최종 결과 출력 (각 DataFrame의 shape 등 확인)
##############################################
print("offer 남은 행:", offer.shape)
print("child_class 남은 행:", child_class.shape)
print("grand_child_class 남은 행:", grand_child_class.shape)
print("error 행:", error.shape)
# Out:
# offer 남은 행: (808, 6)
# child_class 남은 행: (183, 7)
# grand_child_class 남은 행: (0, 7)
# error 행: (166, 7)

# %%
child_class
# Out:
#      CourseCode FacultyCode                                    Session  \
# 0         AB243        SABE        LECTURE COMBINED TO BEI1083/LECTURE
# 1         AB316        SABE        LECTURE COMBINED TO BEI2017/LECTURE
# 2         AB343        SABE        LECTURE COMBINED TO BEI2033/LECTURE
# 3         AB416        SABE    LECTURE 1 COMBINED TO BEI2067/LECTURE 1
# 4         AB416        SABE    LECTURE 2 COMBINED TO BEI2067/LECTURE 2
# ...         ...         ...                                        ...
# 1049      MS201         FAS  LECTURE 2  COMBINED TO BAA2023/LECTURE 2
# 1054   MST1014B      FOSSLA    LECTURE  COMBINED TO PST1014B/LECTURE 1
# 1055   MST1014B      FOSSLA    LECTURE  COMBINED TO PST1014B/LECTURE 2
# 1056   MST1024B      FOSSLA    LECTURE  COMBINED TO PST1024B/LECTURE 1
# 1057   MST1024B      FOSSLA    LECTURE  COMBINED TO PST1024B/LECTURE 2
#
#       Capacity  Min Per Session  \
# 0            5              180
# 1            5              450
# 2            5              180
# 3           10              210
# 4           10              240
# ...        ...              ...
# 1049        10               60
# 1054        10              240
# 1055        10              240
# 1056        10              240
# 1057        10              240
#
#                                                Lecturer extracted_code
# 0                                   NURUL ANIDA MOHAMAD        BEI1083
# 1                                    DR. WONG LEONG YEE        BEI2017
# 2                                       HUMANSON GIMFIL        BEI2033
# 3                ASST. PROF. IDR BAIZURA HANIM BT BIDIN        BEI2067
# 4                ASST. PROF. IDR BAIZURA HANIM BT BIDIN        BEI2067
# ...                                                 ...            ...
# 1049                        ASST. PROF. DR. CHEW LI LEE        BAA2023
# 1054                      ASST. PROF. DR. ZAIDA MUSTAFA       PST1014B
# 1055                      ASST. PROF. DR. ZAIDA MUSTAFA       PST1014B
# 1056  ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHAR...       PST1024B
# 1057  ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHAR...       PST1024B
#
# [183 rows x 7 columns]

# %%
# child_class의 각 행을 순회하며 조건에 맞는 offer 행의 Capacity에 child_class의 Capacity를 합산합니다.
for idx, child_row in child_class.iterrows():
    # 조건: offer의 CourseCode, Min Per Session, Lecturer가 child_row의 extracted_code, Min Per Session, Lecturer와 일치
    mask = (
        (offer['CourseCode'] == child_row['extracted_code']) &
        (offer['Min Per Session'] == child_row['Min Per Session']) &
        (offer['Lecturer'] == child_row['Lecturer'])
    )
    # 일치하는 행이 있다면, offer의 Capacity에 child_row의 Capacity를 더함
    if mask.any():
        offer.loc[mask, 'Capacity'] += child_row['Capacity']

# 결과 확인: 업데이트된 offer 데이터프레임의 Capacity 값
offer
# Out:
#      CourseCode FacultyCode               Session  Capacity  Min Per Session  \
# 6         AB443        SABE               LECTURE        25              180
# 7         AB516        SABE  LECTURE FATHER CLASS        50              450
# 8         AB533        SABE  LECTURE FATHER CLASS        40              180
# 10        AB618        SABE             LECTURE 2        20              240
# 11        AB618        SABE             LECTURE 1        20              210
# ...         ...         ...                   ...       ...              ...
# 1152      SP206      FOSSLA             LECTURE 1        20              180
# 1153      SP206      FOSSLA             LECTURE 2        20              180
# 1154      SP208      FOSSLA              LECTURE          5              120
# 1155      SP208      FOSSLA              LECTURE          5              180
# 1156      SP208      FOSSLA              LECTURE          5               60
#
#                                     Lecturer
# 6                        NURUL ANIDA MOHAMAD
# 7                             LIM KER CHWING
# 8     ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 10                       NURUL ANIDA MOHAMAD
# 11                       NURUL ANIDA MOHAMAD
# ...                                      ...
# 1152             NURUL HIDAYAH BT MOHD SA'AT
# 1153             NURUL HIDAYAH BT MOHD SA'AT
# 1154                       ARMAN IMRAN ASHOK
# 1155                       ARMAN IMRAN ASHOK
# 1156                       ARMAN IMRAN ASHOK
#
# [808 rows x 6 columns]

# %%
import numpy as np

# 기존 조건
conditions = [
    offer['Session'].str.contains('LECTURE & TUTORIAL', na=False, case=False),
    offer['Session'].str.contains('TUTORIAL', na=False, case=False),
    offer['Session'].str.contains('LECTURE', na=False, case=False),
    offer['Session'].str.contains('LAB', na=False, case=False),
    offer['Session'].str.contains('PBL 1', na=False, case=False),
    offer['Session'].str.contains('HAND DRAWING|CAD DRAWING 2|CAD DRAWING 1', na=False, case=False),
    offer['Session'].str.contains('KITCHEN', na=False, case=False),
    offer['Session'].str.contains('OPTOM CLINIC|SOO - EXAM CLINIC', na=False, case=False)
]

# 기존 선택지 + 새 선택지
choices = [
    'GENERAL',
    'TUTORIAL',
    'LECTURE',
    'LAB',
    'PBL',
    'ART',
    'KITCHEN',
    'LECTURE'
]

# 조건을 적용하여 'Category' 열 생성
offer['Category'] = np.select(conditions, choices, default=np.nan)

offer
# Out:
#      CourseCode FacultyCode               Session  Capacity  Min Per Session  \
# 6         AB443        SABE               LECTURE        25              180
# 7         AB516        SABE  LECTURE FATHER CLASS        50              450
# 8         AB533        SABE  LECTURE FATHER CLASS        40              180
# 10        AB618        SABE             LECTURE 2        20              240
# 11        AB618        SABE             LECTURE 1        20              210
# ...         ...         ...                   ...       ...              ...
# 1152      SP206      FOSSLA             LECTURE 1        20              180
# 1153      SP206      FOSSLA             LECTURE 2        20              180
# 1154      SP208      FOSSLA              LECTURE          5              120
# 1155      SP208      FOSSLA              LECTURE          5              180
# 1156      SP208      FOSSLA              LECTURE          5               60
#
#                                     Lecturer Category
# 6                        NURUL ANIDA MOHAMAD  LECTURE
# 7                             LIM KER CHWING  LECTURE
# 8     ASST. PROF. IDR BAIZURA HANIM BT BIDIN  LECTURE
# 10                       NURUL ANIDA MOHAMAD  LECTURE
# 11                       NURUL ANIDA MOHAMAD  LECTURE
# ...                                      ...      ...
# 1152             NURUL HIDAYAH BT MOHD SA'AT  LECTURE
# 1153             NURUL HIDAYAH BT MOHD SA'AT  LECTURE
# 1154                       ARMAN IMRAN ASHOK  LECTURE
# 1155                       ARMAN IMRAN ASHOK  LECTURE
# 1156                       ARMAN IMRAN ASHOK  LECTURE
#
# [808 rows x 7 columns]

# %%
result = offer[offer['CourseCode'].str.lower() == 'bp132']
result
# Out:
#     CourseCode FacultyCode             Session  Capacity  Min Per Session  \
# 541      BP132         FPS           LECTURE 1        60               60
# 542      BP132         FPS           LECTURE 2        60               60
# 543      BP132         FPS           LECTURE 3        60               60
# 544      BP132         FPS          TUTORIAL 1        60               60
# 545      BP132         FPS  LECTURE & TUTORIAL        60               60
#
#                         Lecturer  Category
# 541  PROF. TS. DR. LEE MING TATT   LECTURE
# 542  PROF. TS. DR. LEE MING TATT   LECTURE
# 543  PROF. TS. DR. LEE MING TATT   LECTURE
# 544  PROF. TS. DR. LEE MING TATT  TUTORIAL
# 545  PROF. TS. DR. LEE MING TATT   GENERAL

# %%
mask = ~offer['Category'].str.contains('TUTORIAL|LECTURE|LAB', na=False)
offer[mask]
# Out:
#      CourseCode FacultyCode             Session  Capacity  Min Per Session  \
# 537       BP112         FPS  LECTURE & TUTORIAL       140               60
# 545       BP132         FPS  LECTURE & TUTORIAL        60               60
# 548       BP172         FPS  LECTURE & TUTORIAL        60               60
# 568       BP266         FPS  LECTURE & TUTORIAL        60               60
# 653     BPC2122         FPS  LECTURE & TUTORIAL        20               60
# 839     DEX1034       FETBE       HAND DRAWING         15              120
# 841     DEX1034       FETBE      CAD DRAWING 2         15              120
# 842     DEX1034       FETBE      CAD DRAWING 1         15              120
# 853     DPB1014        FHTM   KITCHEN PRACTICAL        10              360
# 854     DPB1024        FHTM  LECTURE & TUTORIAL        10              180
# 1109      OP422       FOMHS               PBL 1        15              180
#
#                                    Lecturer Category
# 537               PROFESSOR DR. SAAD TAYYAB  GENERAL
# 545             PROF. TS. DR. LEE MING TATT  GENERAL
# 548                    VITHYAH A/P NADARAJA  GENERAL
# 568   SABREEN YOUSIF MOHAMMED ALHASSAN NASR  GENERAL
# 653    ASSOCIATE PROFESSOR DR. MAI CHUN WAI  GENERAL
# 839              TS. AMAR RIDZUAN ABD HAMID      ART
# 841         TS. MUHAMAD FALIQ MOHAMAD NAZER      ART
# 842         TS. MUHAMAD FALIQ MOHAMAD NAZER      ART
# 853      SH MARIA SAHILA BT SYED ALI HASSAN  KITCHEN
# 854                       NURSYAFIQAH RAMLI  GENERAL
# 1109       NOORSHAZANA MAT REJAB @ MD REJAB      PBL

# %% [markdown]
# # classroom

# %%
import pandas as pd
import plotly.express as px

df = pd.read_excel(r"C:\Users\light\Desktop\CSD - Resource Room.xlsx")

Resource_Room = pd.DataFrame(df)
Resource_Room = Resource_Room.drop(labels='Campus', axis=1)
Resource_Room = Resource_Room.drop(labels='Workshop', axis=1)
Resource_Room = Resource_Room[~Resource_Room.apply(lambda row: row.astype(str).str.contains('IMus', case=False, na=False).any(), axis=1)]
Resource_Room = Resource_Room[~(Resource_Room[['Lecture', 'Tutorial', 'Lab']].eq('N').all(axis=1))]
Resource_Room = Resource_Room.fillna('N')
Resource_Room['Capacity'] = Resource_Room['Capacity'].replace('N', '20')
Resource_Room = Resource_Room.drop(Resource_Room[Resource_Room['Capacity'] == 0].index)

print(Resource_Room[Resource_Room['Capacity'] == 'N'])

#조건에 따라 Gerneral한 경우로 분류
conditions = [
    ['Y', 'Y', 'Y']
]
columns_to_check = ['Lecture', 'Tutorial', 'Lab']
General = Resource_Room[Resource_Room[columns_to_check].apply(tuple, axis=1).isin(map(tuple, conditions))]
General.info()

#Gerneral하지 않은 경우를 뺀 나머지 데이터프레임 생성
conditions_to_exclude = [
    ['Y', 'Y', 'N'],
    ['N', 'Y', 'Y']
]
columns_to_check = ['Lecture', 'Tutorial', 'Lab']

#G_Resource_Room = Resource_Room[~Resource_Room[columns_to_check].apply(lambda row: tuple(row) in conditions_to_exclude, axis=1)]
#G_Resource_Room.info()

etc_Room = Resource_Room[~Resource_Room[columns_to_check].apply(tuple, axis=1).isin(map(tuple, conditions))]

#G_Resource_Room_IMus = G_Resource_Room[G_Resource_Room['Description'].str.contains('IMus', na=False) | G_Resource_Room['Resource Code'].str.contains('IMus', na=False)]
Kitchen = etc_Room[etc_Room.apply(lambda row: row.astype(str).str.contains('Kitchen', regex=False).any(), axis=1)]
Design = etc_Room[etc_Room['Description'].str.contains('DESIGN', case=False, na=False)]
df_combined = pd.concat([Kitchen, Design])
LL = etc_Room[~etc_Room.apply(tuple, axis=1).isin(df_combined.apply(tuple, axis=1))]

#조건에 따라 Gerneral한 경우로 분류
conditions = [
    ['N', 'N', 'Y']
]
columns_to_check = ['Lecture', 'Tutorial', 'Lab']
Lab = LL[LL[columns_to_check].apply(tuple, axis=1).isin(map(tuple, conditions)) & ~LL.apply(tuple, axis=1).isin(df_combined.apply(tuple, axis=1))]

#조건에 따라 Gerneral한 경우로 분류
conditions = [
    ['Y', 'N', 'N']
]
columns_to_check = ['Lecture', 'Tutorial', 'Lab']
Lecture = LL[LL[columns_to_check].apply(tuple, axis=1).isin(map(tuple, conditions)) & ~LL.apply(tuple, axis=1).isin(df_combined.apply(tuple, axis=1))]

df_combined = pd.concat([Lab, Lecture])
ETC = LL[~LL.apply(tuple, 1).isin(df_combined.apply(tuple, 1))]

import pandas as pd

General['Type'] = 'General'
Lab['Type'] = 'Lab'
Kitchen['Type'] = 'Kitchen'
Design['Type'] = 'Art'
Lecture['Type'] = 'Lecture'
ETC['Type'] = 'Etc'

df_final = pd.concat([General, ETC, Kitchen, Design, Lab, Lecture], ignore_index=True)
df_final = df_final.drop_duplicates(keep='first')

df_final.loc[df_final['Resource Code'].str.contains('PBL', na=False), 'Type'] = 'PBL'
df_final[df_final['Type'] == 'PBL']
df_final['Resource Code'] = df_final['Resource Code'].str.upper()
df_final['Description'] = df_final['Description'].str.upper()
df_final['Resource Status'] = df_final['Resource Status'].str.upper()
df_final['Type'] = df_final['Type'].str.upper()
df_final.rename(columns={'Type': 'Category'}, inplace=True)
classroom = df_final.copy()
classroom
# Out:
# Empty DataFrame
# Columns: [Resource Code, Description, Capacity, Lecture, Tutorial, Lab, Resource Status]
# Index: []
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 16 to 171
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Resource Code    7 non-null      object
#  1   Description      7 non-null      object
#  2   Capacity         7 non-null      int64
#  3   Lecture          7 non-null      object
#  4   Tutorial         7 non-null      object
#  5   Lab              7 non-null      object
#  6   Resource Status  7 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 448.0+ bytes
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   General['Type'] = 'General'
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lab['Type'] = 'Lab'
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kitchen['Type'] = 'Kitchen'
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Design['Type'] = 'Art'
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Lecture['Type'] = 'Lecture'
# C:\Users\light\AppData\Local\Temp\ipykernel_7096\3586962336.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETC['Type'] = 'Etc'
#                                          Resource Code  \
# 0                                            MPH - GBS
# 1                                               C3M04B
# 2                                                C3M05
# 3                                                 C314
# 4    ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTR...
# ..                                                 ...
# 179                                PETROL CHEMICAL LAB
# 180                                       ADV CHEM LAB
# 181  POSTGRADUATE RESEARCH & SYSTEM ANALYTICAL LABO...
# 182                                             FASMR2
# 183                                 GROUP THERAPY ROOM
#
#                                            Description  Capacity Lecture  \
# 0                            MPH - [MULTIPURPOSE HALL]       100       Y
# 1                   C3M04 - [C3M04B-SABE COMPUTER LAB]        30       Y
# 2                         C3M05 - [C3M05-COMPUTER LAB]        30       Y
# 3                           C314 - [MICROTEACHING LAB]        30       Y
# 4    ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTR...        30       Y
# ..                                                 ...       ...     ...
# 179    PETROL CHEMICAL STATISTICAL ANALYSIS LABORATORY        15       N
# 180             ADVANCE CHEMICAL TECHNOLOGY LABORATORY        15       N
# 181  POSTGRADUATE RESEARCH & SYSTEM ANALYTICAL LABO...        15       N
# 182                                           FAS MR 2        10       N
# 183                                 GROUP THERAPY ROOM        15       Y
#
#     Tutorial Lab Resource Status Category
# 0          Y   Y          ACTIVE  GENERAL
# 1          Y   Y          ACTIVE  GENERAL
# 2          Y   Y          ACTIVE  GENERAL
# 3          Y   Y          ACTIVE  GENERAL
# 4          Y   Y          ACTIVE  GENERAL
# ..       ...  ..             ...      ...
# 179        N   Y          ACTIVE      LAB
# 180        N   Y          ACTIVE      LAB
# 181        N   Y          ACTIVE      LAB
# 182        N   Y          ACTIVE      LAB
# 183        N   N          ACTIVE  LECTURE
#
# [184 rows x 8 columns]

# %% [markdown]
# # Model

# %%
import pandas as pd
import numpy as np
import random
import math

# -------------------------------
# 1. Offer 데이터 전처리: 세션 분할
# -------------------------------
def split_sessions(offer):
    """
    offer 데이터에서 'Min Per Session'이 180분을 초과하는 경우,
    180분 이하 단위로 분할하여 여러 세션(row)으로 반환합니다.
    예) 450분 → 180, 180, 90 (각각 _part1, _part2, _part3 로 Session 구분)
    """
    sessions = []
    for idx, row in offer.iterrows():
        total_minutes = row['Min Per Session']
        if total_minutes <= 180:
            sessions.append(row.copy())
        else:
            remaining = total_minutes
            part = 1
            while remaining > 0:
                new_row = row.copy()
                chunk = min(180, remaining)
                new_row['Min Per Session'] = chunk
                new_row['Session'] = f"{row['Session']}_part{part}"
                sessions.append(new_row)
                remaining -= chunk
                part += 1
    return pd.DataFrame(sessions)

# offer 데이터가 이미 로드되어 있다고 가정
# 인덱스 재설정 추가!
df_sessions = split_sessions(offer).reset_index(drop=True)
print("총 세션 수 (분할 후):", len(df_sessions))


# -------------------------------
# 2. 시간 슬롯(Time Slot) 정의 (월~금, 08시~21시, 1시간 단위)
# -------------------------------
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

def get_valid_start_hours(duration_hours):
    """
    주어진 세션의 지속시간(duration_hours)이 있을 때,
    해당 세션이 하루 08:00~21:00 내에 배정될 수 있는 시작시간 목록을 반환.
    (start_hour + duration_hours <= 21)
    """
    return [h for h in range(8, 22) if h + duration_hours <= 21]


# -------------------------------
# 3. 랜덤 서치: 스케줄(시간표) 생성 함수
# -------------------------------
def generate_random_schedule(df_sessions, classroom):
    """
    각 세션에 대해 다음을 수행:
      - 해당 세션의 요구조건(수용인원, 강의/튜토리얼 vs. Lab)을 만족하는 강의실 후보에서 랜덤 선택
      - 월~금 중 랜덤 요일 선택
      - 세션의 지속시간(분)을 1시간 단위(올림)로 계산 후, 시작시간 후보 중 랜덤 선택
    """
    schedule = []
    for idx, session in df_sessions.iterrows():
        # 1. 세션의 지속시간(시간 단위): 1시간 단위 올림 (예: 90분 → 2시간, 180분 → 3시간)
        duration_hours = math.ceil(session['Min Per Session'] / 60)
        
        # 2. 강의실 후보 선정: 용량 조건 확인
        valid_rooms = classroom[classroom['Capacity'] >= session['Capacity']]
        
        # 3. 강의실 유형 조건
        # Lab 강의는 반드시 Lab 강의실에 배정 (그 외는 일반 강의실: GENERAL 또는 LECTURE)
        session_cat = session['Category'].upper()
        if session_cat == "LAB":
            valid_rooms = valid_rooms[valid_rooms['Category'].str.upper() == "LAB"]
        else:
            valid_rooms = valid_rooms[valid_rooms['Category'].str.upper().isin(["GENERAL", "LECTURE"])]
        
        # 4. 강의실 후보가 없으면 None 할당
        if valid_rooms.empty:
            assigned_room = None
        else:
            assigned_room = valid_rooms.sample(1)['Resource Code'].values[0]
        
        # 5. 요일과 시작시간 랜덤 선택
        assigned_day = random.choice(days)
        valid_hours = get_valid_start_hours(duration_hours)
        if not valid_hours:
            assigned_hour = None
        else:
            assigned_hour = random.choice(valid_hours)
        
        assignment = {
            'session_index': idx,               # df_sessions의 인덱스를 저장 (후에 세부정보 참조)
            'course': session['CourseCode'],
            'lecturer': session['Lecturer'],
            'category': session['Category'],
            'required_duration': duration_hours,  # 필요한 연속 슬롯 수
            'assigned_classroom': assigned_room,
            'day': assigned_day,
            'start_hour': assigned_hour,
            'end_hour': assigned_hour + duration_hours if assigned_hour is not None else None
        }
        schedule.append(assignment)
    return schedule


# -------------------------------
# 4. 스코어링 함수: 스케줄 평가 (제약 위반에 따른 페널티 부여)
# -------------------------------
def score_schedule(schedule, df_sessions, classroom):
    """
    각 스케줄의 제약 위반 여부에 따라 패널티를 부여합니다.
    
    제약 조건:
      - 할당된 강의실이나 시작시간이 None이면 heavy penalty
      - 시간대가 08:00~21:00 내에 있어야 함
      - 강의실 용량 부족 → penalty
      - Lab 강의는 반드시 Lab 강의실에 배정되어야 함
      - 동일 요일에 동일 강의실 또는 동일 강사가 시간 겹침이 있으면 penalty
    """
    penalty = 0
    n = len(schedule)
    
    # 각 assignment를 검사
    for i in range(n):
        a = schedule[i]
        # 만약 강의실이나 시작시간이 할당되지 않았다면 heavy penalty
        if a['assigned_classroom'] is None or a['start_hour'] is None:
            penalty += 10
            continue
        
        # 시간대 범위 검사 (08시~21시)
        if a['start_hour'] < 8 or a['end_hour'] > 21:
            penalty += 5
        
        # 강의실 정보 획득
        cls = classroom[classroom['Resource Code'] == a['assigned_classroom']]
        if cls.empty:
            penalty += 5
        else:
            room_capacity = cls.iloc[0]['Capacity']
            required_capacity = df_sessions.iloc[a['session_index']]['Capacity']
            if room_capacity < required_capacity:
                penalty += 5
            
            room_cat = cls.iloc[0]['Category'].upper()
            # Lab 강의 검사
            if a['category'].upper() == "LAB" and room_cat != "LAB":
                penalty += 5
        
        # 동일 요일 내 다른 세션과 시간 겹침 검사
        for j in range(i+1, n):
            b = schedule[j]
            if a['day'] != b['day']:
                continue
            # 같은 강의실 충돌 검사
            if a['assigned_classroom'] == b['assigned_classroom']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 3
            # 같은 강사 충돌 검사
            if a['lecturer'] == b['lecturer']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 3
                    
    return penalty


# -------------------------------
# 5. 랜덤 서치를 통한 최적 스케줄 탐색
# -------------------------------
def random_search(df_sessions, classroom, iterations=10000):
    best_schedule = None
    best_score = float('inf')
    for it in range(iterations):
        sched = generate_random_schedule(df_sessions, classroom)
        score = score_schedule(sched, df_sessions, classroom)
        if score < best_score:
            best_score = score
            best_schedule = sched
        if it % 100 == 0:
            print(f"Iteration {it}: Best score so far = {best_score}")
    return best_schedule, best_score


# -------------------------------
# 실행 예시
# -------------------------------
# offer와 classroom 데이터는 이미 전처리되어 있다고 가정합니다.
best_schedule, best_score = random_search(df_sessions, classroom, iterations=1000)

print("\n최종 스케줄 점수:", best_score)
print("최적 스케줄 할당:")
for assignment in best_schedule:
    print(assignment)
# Out:
# 총 세션 수 (분할 후): 870
# Iteration 0: Best score so far = 10699
# Iteration 100: Best score so far = 10228
# Iteration 200: Best score so far = 10210
# Iteration 300: Best score so far = 10105
# Iteration 400: Best score so far = 10105
# Iteration 500: Best score so far = 10105
# Iteration 600: Best score so far = 10105
# Iteration 700: Best score so far = 10105
# Iteration 800: Best score so far = 10105
# Iteration 900: Best score so far = 10105
#
# 최종 스케줄 점수: 10105
# 최적 스케줄 할당:
# {'session_index': 0, 'course': 'AB443', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 1, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 2, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 3, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 4, 'course': 'AB533', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 5, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 6, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Wed', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 7, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 8, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 9, 'course': 'AB623', 'lecturer': 'AR. TEE KHAY MEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 10, 'course': 'AB633', 'lecturer': 'TAN HAN LEONG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 11, 'course': 'AD133', 'lecturer': 'AMAR MUHAMMAD RAMLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 12, 'course': 'AD133', 'lecturer': 'AMAR MUHAMMAD RAMLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 13, 'course': 'AD332', 'lecturer': 'NOR SYAWALLINA AZMAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 14, 'course': 'AD332', 'lecturer': 'NOR SYAWALLINA AZMAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Wed', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 15, 'course': 'AI663', 'lecturer': 'NUR RAFIDA HAMZAH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Tue', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 16, 'course': 'AI663', 'lecturer': 'NUR RAFIDA HAMZAH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 17, 'course': 'AR423', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 18, 'course': 'AR433', 'lecturer': 'TS. DR. KHAIRUL ZAHREEN MOHD AROF', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Thu', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 19, 'course': 'AR453', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 20, 'course': 'AR533', 'lecturer': 'AR. NORIZAN DAUD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 21, 'course': 'AR724', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 22, 'course': 'AR853', 'lecturer': 'JAMES LIM CHIN WAI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 23, 'course': 'AR873', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 24, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 25, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 26, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 27, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 28, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 29, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 30, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 31, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 32, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 33, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 34, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 35, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 36, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Tue', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 37, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 38, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Mon', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 39, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 40, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 41, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 42, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 43, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': 'CHEM1', 'day': 'Fri', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 44, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Fri', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 45, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 46, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 47, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 48, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 49, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 50, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Wed', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 51, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Thu', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 52, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 53, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 54, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Mon', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 55, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 56, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 57, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Fri', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 58, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 59, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 60, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 61, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Mon', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 62, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 63, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 64, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 65, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 66, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 67, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 68, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 69, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 70, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 71, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 72, 'course': 'BAN2024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': 'BIOCHEM', 'day': 'Wed', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 73, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 74, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 75, 'course': 'BBA1093', 'lecturer': 'DR. MARCIA EDNA SANTHANARAJAN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 76, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 77, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 78, 'course': 'BBA1093', 'lecturer': 'DR. MARCIA EDNA SANTHANARAJAN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 79, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 80, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 81, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 82, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 83, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 84, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 85, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 86, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 87, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 88, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 89, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 90, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 91, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 92, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 93, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 94, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 95, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 96, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 97, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 98, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 99, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 100, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 101, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 102, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 103, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 104, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 105, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 106, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 107, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 108, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 109, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 110, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 111, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 112, 'course': 'BBB1023', 'lecturer': 'THILAGAVATHI A/P MUTTU', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 113, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 114, 'course': 'BBB1023', 'lecturer': 'THILAGAVATHI A/P MUTTU', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 115, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 116, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 117, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 118, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 119, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 120, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 121, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 122, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 123, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 124, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 125, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 126, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 127, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 128, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 129, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Wed', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 130, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 131, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 132, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 133, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 134, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Wed', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 135, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Thu', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 136, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Thu', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 137, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 138, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 139, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 140, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 141, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Tue', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 142, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 143, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 144, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 145, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 146, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 147, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 148, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 149, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 150, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 151, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 152, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 153, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 154, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 155, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 156, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 157, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 158, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 159, 'course': 'BEA1023', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 160, 'course': 'BEA1033', 'lecturer': 'INTAN LIANA SAMSUDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 161, 'course': 'BEA1043', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 162, 'course': 'BEA1043', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 163, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 164, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 165, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 166, 'course': 'BEA1063', 'lecturer': 'DR. KHOO FONG YI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 167, 'course': 'BEA1073', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Tue', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 168, 'course': 'BEA1083', 'lecturer': 'TS. MALIZA ISMAIL JAMAIL', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 169, 'course': 'BEA1083', 'lecturer': 'TS. MALIZA ISMAIL JAMAIL', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 170, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 171, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 172, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 173, 'course': 'BEA2023', 'lecturer': 'INTAN LIANA SAMSUDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 174, 'course': 'BEA2033', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 175, 'course': 'BEA2043', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 176, 'course': 'BEA2053', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 177, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 178, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 179, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 180, 'course': 'BEA2073', 'lecturer': 'DR. KHOO FONG YI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 181, 'course': 'BEA2083', 'lecturer': 'ASSISTANT PROFESSOR DR. ZHAO SHENGHUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 182, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 183, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Mon', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 184, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 185, 'course': 'BEA3023', 'lecturer': 'PROFESSOR DR. NANGKULA UTABERTA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 186, 'course': 'BEA3034', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 187, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 188, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 189, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 190, 'course': 'BEA3066', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 191, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 192, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 193, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 194, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 195, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 196, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 197, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Fri', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 198, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Tue', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 199, 'course': 'BEI1063', 'lecturer': 'LEONG YEAN TUCK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 200, 'course': 'BEI1063', 'lecturer': 'LEONG YEAN TUCK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 201, 'course': 'BEI1073', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 202, 'course': 'BEI1083', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 203, 'course': 'BEI2017', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 204, 'course': 'BEI2017', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 205, 'course': 'BEI2017', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 206, 'course': 'BEI2023', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 207, 'course': 'BEI2033', 'lecturer': 'HUMANSON GIMFIL', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 208, 'course': 'BEI2043', 'lecturer': 'SHAWN LEISHMAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 209, 'course': 'BEI2053', 'lecturer': 'FOO HSIANG HSIEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 210, 'course': 'BEI2067', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 211, 'course': 'BEI2067', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 212, 'course': 'BEI2067', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 213, 'course': 'BEI2067', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 214, 'course': 'BEI2074', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 215, 'course': 'BEI2083', 'lecturer': 'NOR ZALINA MD NOR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 216, 'course': 'BEI4043', 'lecturer': 'NOR ZALINA MD NOR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# ...
# {'session_index': 800, 'course': 'OP322', 'lecturer': 'NOORSHAZANA MAT REJAB @ MD REJAB', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 801, 'course': 'OP323', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 802, 'course': 'OP324', 'lecturer': 'DR. MUHAMMAD IKMAL MOHAMMAD KAMIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 803, 'course': 'OP324', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 804, 'course': 'OP325', 'lecturer': 'AL KHUSAIRI AIDID ABU ASMARA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 805, 'course': 'OP325', 'lecturer': 'AL KHUSAIRI AIDID ABU ASMARA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 806, 'course': 'OP413', 'lecturer': 'ASSISTANT PROFESSOR DR. TEOH SWEE CHAI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Tue', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 807, 'course': 'OP414', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 808, 'course': 'OP415', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Fri', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 809, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 810, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Mon', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 811, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 812, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 813, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 814, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 815, 'course': 'OP422', 'lecturer': 'NOORSHAZANA MAT REJAB @ MD REJAB', 'category': 'PBL', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 816, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 817, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Thu', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 818, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Fri', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 819, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 820, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Mon', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 821, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 822, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Fri', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 823, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 824, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Thu', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 825, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 826, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 827, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 828, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 829, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 830, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 831, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 832, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 833, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 834, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 835, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 836, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 837, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 838, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 839, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 840, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 841, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 842, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 843, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Thu', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 844, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 845, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 846, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Fri', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 847, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 848, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 849, 'course': 'SM101', 'lecturer': 'ASST. PROF. DR. ALWYN LAU WING WANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 850, 'course': 'SM101', 'lecturer': 'ASST. PROF. DR. ALWYN LAU WING WANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 851, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 852, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 853, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 854, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 855, 'course': 'SM114', 'lecturer': 'MOHD FARIZI JAMALUDDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 856, 'course': 'SM114', 'lecturer': 'MOHD FARIZI JAMALUDDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 857, 'course': 'SM115', 'lecturer': 'ASST. PROF. DR. VIMALA A/P GOVINDASAMY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 858, 'course': 'SM115', 'lecturer': 'ASST. PROF. DR. VIMALA A/P GOVINDASAMY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 859, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 860, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 861, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 862, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 863, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 864, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 865, 'course': 'SP206', 'lecturer': "NURUL HIDAYAH BT MOHD SA'AT", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 866, 'course': 'SP206', 'lecturer': "NURUL HIDAYAH BT MOHD SA'AT", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 867, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 868, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 869, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 14, 'end_hour': 15}

# %%
import pandas as pd
import numpy as np
import random
import math

# -------------------------------
# 1. Offer 데이터 전처리: 세션 분할
# -------------------------------
def split_sessions(offer):
    """
    offer 데이터에서 'Min Per Session'이 180분을 초과하는 경우,
    180분 이하 단위로 분할하여 여러 세션(row)으로 반환합니다.
    예) 450분 → 180, 180, 90 (각각 _part1, _part2, _part3 로 Session 구분)
    """
    sessions = []
    for idx, row in offer.iterrows():
        total_minutes = row['Min Per Session']
        if total_minutes <= 180:
            sessions.append(row.copy())
        else:
            remaining = total_minutes
            part = 1
            while remaining > 0:
                new_row = row.copy()
                chunk = min(180, remaining)
                new_row['Min Per Session'] = chunk
                new_row['Session'] = f"{row['Session']}_part{part}"
                sessions.append(new_row)
                remaining -= chunk
                part += 1
    return pd.DataFrame(sessions)

# offer 데이터가 이미 로드되어 있다고 가정
# 인덱스 재설정 추가!
df_sessions = split_sessions(offer).reset_index(drop=True)
print("총 세션 수 (분할 후):", len(df_sessions))


# -------------------------------
# 2. 시간 슬롯(Time Slot) 정의 (월~금, 08시~21시, 1시간 단위)
# -------------------------------
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

def get_valid_start_hours(duration_hours):
    """
    주어진 세션의 지속시간(duration_hours)이 있을 때,
    해당 세션이 하루 08:00~21:00 내에 배정될 수 있는 시작시간 목록을 반환.
    (start_hour + duration_hours <= 21)
    """
    return [h for h in range(8, 22) if h + duration_hours <= 21]


# -------------------------------
# 3. 랜덤 서치: 스케줄(시간표) 생성 함수
# -------------------------------
def generate_random_schedule(df_sessions, classroom):
    """
    각 세션에 대해 다음을 수행:
      - 해당 세션의 요구조건(수용인원, 강의/튜토리얼 vs. Lab)을 만족하는 강의실 후보에서 랜덤 선택
      - 월~금 중 랜덤 요일 선택
      - 세션의 지속시간(분)을 1시간 단위(올림)로 계산 후, 시작시간 후보 중 랜덤 선택
    """
    schedule = []
    for idx, session in df_sessions.iterrows():
        # 1. 세션의 지속시간(시간 단위): 1시간 단위 올림 (예: 90분 → 2시간, 180분 → 3시간)
        duration_hours = math.ceil(session['Min Per Session'] / 60)
        
        # 2. 강의실 후보 선정: 용량 조건 확인
        valid_rooms = classroom[classroom['Capacity'] >= session['Capacity']]
        
        # 3. 강의실 유형 조건
        # Lab 강의는 반드시 Lab 강의실에 배정 (그 외는 일반 강의실: GENERAL 또는 LECTURE)
        session_cat = session['Category'].upper()
        if session_cat == "LAB":
            valid_rooms = valid_rooms[valid_rooms['Category'].str.upper() == "LAB"]
        else:
            valid_rooms = valid_rooms[valid_rooms['Category'].str.upper().isin(["GENERAL", "LECTURE"])]
        
        # 4. 강의실 후보가 없으면 None 할당
        if valid_rooms.empty:
            assigned_room = None
        else:
            assigned_room = valid_rooms.sample(1)['Resource Code'].values[0]
        
        # 5. 요일과 시작시간 랜덤 선택
        assigned_day = random.choice(days)
        valid_hours = get_valid_start_hours(duration_hours)
        if not valid_hours:
            assigned_hour = None
        else:
            assigned_hour = random.choice(valid_hours)
        
        assignment = {
            'session_index': idx,               # df_sessions의 인덱스를 저장 (후에 세부정보 참조)
            'course': session['CourseCode'],
            'lecturer': session['Lecturer'],
            'category': session['Category'],
            'required_duration': duration_hours,  # 필요한 연속 슬롯 수
            'assigned_classroom': assigned_room,
            'day': assigned_day,
            'start_hour': assigned_hour,
            'end_hour': assigned_hour + duration_hours if assigned_hour is not None else None
        }
        schedule.append(assignment)
    return schedule


# -------------------------------
# 4. 스코어링 함수: 스케줄 평가 (제약 위반에 따른 페널티 부여)
# -------------------------------
def score_schedule(schedule, df_sessions, classroom):
    """
    각 스케줄의 제약 위반 여부에 따라 패널티를 부여합니다.
    
    제약 조건:
      - 할당된 강의실이나 시작시간이 None이면 heavy penalty
      - 시간대가 08:00~21:00 내에 있어야 함
      - 강의실 용량 부족 → penalty
      - Lab 강의는 반드시 Lab 강의실에 배정되어야 함
      - 동일 요일에 동일 강의실 또는 동일 강사가 시간 겹침이 있으면 penalty
    """
    penalty = 0
    n = len(schedule)
    
    # 각 assignment를 검사
    for i in range(n):
        a = schedule[i]
        # 만약 강의실이나 시작시간이 할당되지 않았다면 heavy penalty
        if a['assigned_classroom'] is None or a['start_hour'] is None:
            penalty += 10
            continue
        
        # 시간대 범위 검사 (08시~21시)
        if a['start_hour'] < 8 or a['end_hour'] > 21:
            penalty += 5
        
        # 강의실 정보 획득
        cls = classroom[classroom['Resource Code'] == a['assigned_classroom']]
        if cls.empty:
            penalty += 5
        else:
            room_capacity = cls.iloc[0]['Capacity']
            required_capacity = df_sessions.iloc[a['session_index']]['Capacity']
            if room_capacity < required_capacity:
                penalty += 5
            
            room_cat = cls.iloc[0]['Category'].upper()
            # Lab 강의 검사
            if a['category'].upper() == "LAB" and room_cat != "LAB":
                penalty += 5
        
        # 동일 요일 내 다른 세션과 시간 겹침 검사
        for j in range(i+1, n):
            b = schedule[j]
            if a['day'] != b['day']:
                continue
            # 같은 강의실 충돌 검사
            if a['assigned_classroom'] == b['assigned_classroom']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 3
            # 같은 강사 충돌 검사
            if a['lecturer'] == b['lecturer']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 3
                    
    return penalty


# -------------------------------
# 5. 랜덤 서치를 통한 최적 스케줄 탐색
# -------------------------------
def random_search(df_sessions, classroom, iterations=10000):
    best_schedule = None
    best_score = float('inf')
    for it in range(iterations):
        sched = generate_random_schedule(df_sessions, classroom)
        score = score_schedule(sched, df_sessions, classroom)
        if score < best_score:
            best_score = score
            best_schedule = sched
        if it % 100 == 0:
            print(f"Iteration {it}: Best score so far = {best_score}")
    return best_schedule, best_score


# -------------------------------
# 실행 예시
# -------------------------------
# offer와 classroom 데이터는 이미 전처리되어 있다고 가정합니다.
best_schedule, best_score = random_search(df_sessions, classroom, iterations=10000)

print("\n최종 스케줄 점수:", best_score)
print("최적 스케줄 할당:")
for assignment in best_schedule:
    print(assignment)
# Out:
# 총 세션 수 (분할 후): 870
# Iteration 0: Best score so far = 10708
# Iteration 100: Best score so far = 10129
# Iteration 200: Best score so far = 10129
# Iteration 300: Best score so far = 10129
# Iteration 400: Best score so far = 10129
# Iteration 500: Best score so far = 9988
# Iteration 600: Best score so far = 9958
# Iteration 700: Best score so far = 9958
# Iteration 800: Best score so far = 9958
# Iteration 900: Best score so far = 9958
# Iteration 1000: Best score so far = 9958
# Iteration 1100: Best score so far = 9958
# Iteration 1200: Best score so far = 9958
# Iteration 1300: Best score so far = 9958
# Iteration 1400: Best score so far = 9958
# Iteration 1500: Best score so far = 9958
# Iteration 1600: Best score so far = 9946
# Iteration 1700: Best score so far = 9946
# Iteration 1800: Best score so far = 9946
# Iteration 1900: Best score so far = 9946
# Iteration 2000: Best score so far = 9946
# Iteration 2100: Best score so far = 9946
# Iteration 2200: Best score so far = 9925
# Iteration 2300: Best score so far = 9925
# Iteration 2400: Best score so far = 9925
# Iteration 2500: Best score so far = 9925
# Iteration 2600: Best score so far = 9925
# Iteration 2700: Best score so far = 9925
# Iteration 2800: Best score so far = 9925
# Iteration 2900: Best score so far = 9925
# Iteration 3000: Best score so far = 9925
# Iteration 3100: Best score so far = 9925
# Iteration 3200: Best score so far = 9925
# Iteration 3300: Best score so far = 9925
# Iteration 3400: Best score so far = 9925
# Iteration 3500: Best score so far = 9925
# Iteration 3600: Best score so far = 9925
# Iteration 3700: Best score so far = 9925
# Iteration 3800: Best score so far = 9925
# Iteration 3900: Best score so far = 9925
# Iteration 4000: Best score so far = 9925
# Iteration 4100: Best score so far = 9781
# Iteration 4200: Best score so far = 9781
# Iteration 4300: Best score so far = 9781
# Iteration 4400: Best score so far = 9781
# Iteration 4500: Best score so far = 9781
# Iteration 4600: Best score so far = 9781
# Iteration 4700: Best score so far = 9781
# Iteration 4800: Best score so far = 9781
# Iteration 4900: Best score so far = 9781
# Iteration 5000: Best score so far = 9781
# Iteration 5100: Best score so far = 9781
# Iteration 5200: Best score so far = 9781
# Iteration 5300: Best score so far = 9781
# Iteration 5400: Best score so far = 9781
# Iteration 5500: Best score so far = 9781
# Iteration 5600: Best score so far = 9781
# Iteration 5700: Best score so far = 9781
# Iteration 5800: Best score so far = 9781
# Iteration 5900: Best score so far = 9781
# Iteration 6000: Best score so far = 9781
# Iteration 6100: Best score so far = 9781
# Iteration 6200: Best score so far = 9781
# Iteration 6300: Best score so far = 9781
# Iteration 6400: Best score so far = 9781
# Iteration 6500: Best score so far = 9781
# Iteration 6600: Best score so far = 9781
# Iteration 6700: Best score so far = 9781
# Iteration 6800: Best score so far = 9781
# Iteration 6900: Best score so far = 9781
# Iteration 7000: Best score so far = 9781
# Iteration 7100: Best score so far = 9781
# Iteration 7200: Best score so far = 9781
# Iteration 7300: Best score so far = 9781
# Iteration 7400: Best score so far = 9781
# Iteration 7500: Best score so far = 9781
# Iteration 7600: Best score so far = 9781
# Iteration 7700: Best score so far = 9781
# Iteration 7800: Best score so far = 9781
# Iteration 7900: Best score so far = 9781
# Iteration 8000: Best score so far = 9781
# Iteration 8100: Best score so far = 9781
# Iteration 8200: Best score so far = 9781
# Iteration 8300: Best score so far = 9781
# Iteration 8400: Best score so far = 9781
# Iteration 8500: Best score so far = 9781
# Iteration 8600: Best score so far = 9781
# Iteration 8700: Best score so far = 9781
# Iteration 8800: Best score so far = 9781
# Iteration 8900: Best score so far = 9781
# Iteration 9000: Best score so far = 9781
# Iteration 9100: Best score so far = 9781
# Iteration 9200: Best score so far = 9781
# Iteration 9300: Best score so far = 9781
# Iteration 9400: Best score so far = 9781
# Iteration 9500: Best score so far = 9781
# Iteration 9600: Best score so far = 9781
# Iteration 9700: Best score so far = 9781
# Iteration 9800: Best score so far = 9781
# Iteration 9900: Best score so far = 9781
#
# 최종 스케줄 점수: 9781
# 최적 스케줄 할당:
# {'session_index': 0, 'course': 'AB443', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 1, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 2, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 3, 'course': 'AB516', 'lecturer': 'LIM KER CHWING', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 4, 'course': 'AB533', 'lecturer': 'ASST. PROF. IDR BAIZURA HANIM BT BIDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 5, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 6, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 7, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Fri', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 8, 'course': 'AB618', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 9, 'course': 'AB623', 'lecturer': 'AR. TEE KHAY MEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 10, 'course': 'AB633', 'lecturer': 'TAN HAN LEONG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 11, 'course': 'AD133', 'lecturer': 'AMAR MUHAMMAD RAMLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Fri', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 12, 'course': 'AD133', 'lecturer': 'AMAR MUHAMMAD RAMLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Fri', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 13, 'course': 'AD332', 'lecturer': 'NOR SYAWALLINA AZMAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 14, 'course': 'AD332', 'lecturer': 'NOR SYAWALLINA AZMAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 15, 'course': 'AI663', 'lecturer': 'NUR RAFIDA HAMZAH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 16, 'course': 'AI663', 'lecturer': 'NUR RAFIDA HAMZAH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 17, 'course': 'AR423', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 18, 'course': 'AR433', 'lecturer': 'TS. DR. KHAIRUL ZAHREEN MOHD AROF', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 19, 'course': 'AR453', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 20, 'course': 'AR533', 'lecturer': 'AR. NORIZAN DAUD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 21, 'course': 'AR724', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 22, 'course': 'AR853', 'lecturer': 'JAMES LIM CHIN WAI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 23, 'course': 'AR873', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 24, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 25, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 26, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 27, 'course': 'BAA2023', 'lecturer': 'ASST. PROF. DR. CHEW LI LEE', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 28, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 29, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 30, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 31, 'course': 'BAB1044', 'lecturer': 'DR. LAU YIN YIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 32, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 33, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 34, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Thu', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 35, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 36, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 37, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 38, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 39, 'course': 'BAB1053', 'lecturer': 'ASSOC. PROF. DR. ERIC CHAN WEI CHIANG', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Wed', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 40, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 41, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 42, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 43, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': 'C LAB C', 'day': 'Tue', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 44, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 45, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Wed', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 46, 'course': 'BAC1064', 'lecturer': 'DR. REVATHI A/P RAJAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 47, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 48, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 49, 'course': 'BAF1024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 50, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 51, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 52, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Thu', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 53, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 54, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 55, 'course': 'BAN1023', 'lecturer': 'DR. SHASHIKALA SIVAPATHY', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 56, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 57, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 58, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Mon', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 59, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 60, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 61, 'course': 'BAN1042', 'lecturer': 'DR. NURLIYANA ABDUL RAZAK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 62, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 63, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 64, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 65, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 66, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 67, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 68, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 69, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 70, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 71, 'course': 'BAN1054', 'lecturer': 'ASST. PROF. DR. BASKARAN GUNASEKARAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 72, 'course': 'BAN2024', 'lecturer': 'PROF. DR. NYAM KAR LIN', 'category': 'LAB', 'required_duration': 3, 'assigned_classroom': 'POWER LAB', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 73, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 74, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 75, 'course': 'BBA1093', 'lecturer': 'DR. MARCIA EDNA SANTHANARAJAN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 76, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 77, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 78, 'course': 'BBA1093', 'lecturer': 'DR. MARCIA EDNA SANTHANARAJAN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 79, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 80, 'course': 'BBA1093', 'lecturer': 'ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 81, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 82, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 83, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 84, 'course': 'BBA1703', 'lecturer': 'BRAHAM RAHUL RAM A/L JAMNADAS', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 85, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 86, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 87, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 88, 'course': 'BBA2033', 'lecturer': 'ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 89, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 90, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 91, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 92, 'course': 'BBA2223', 'lecturer': 'SHAKERIN ISMAIL', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 93, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 94, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 95, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 96, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 97, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 98, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 99, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 100, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 101, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 102, 'course': 'BBB1013', 'lecturer': 'DR. NORLIZA OMAR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 103, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 104, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 105, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 106, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 107, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 108, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 109, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 110, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 111, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 112, 'course': 'BBB1023', 'lecturer': 'THILAGAVATHI A/P MUTTU', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 113, 'course': 'BBB1023', 'lecturer': 'DR. WONG HOONG SANG', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 114, 'course': 'BBB1023', 'lecturer': 'THILAGAVATHI A/P MUTTU', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 115, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 116, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 117, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 118, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 119, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 120, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 121, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 122, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 123, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 124, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 125, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 126, 'course': 'BBB1033', 'lecturer': 'DR. SOO XIN LIN', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 127, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Tue', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 128, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Fri', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 129, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Thu', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 130, 'course': 'BBL1013', 'lecturer': 'ASST. PROF. DR. NOORSIAH AHMAD', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 131, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 132, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 133, 'course': 'BBM1073', 'lecturer': 'DR. NURKHALIDA MAKMOR', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 134, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 135, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Fri', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 136, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 19, 'end_hour': 20}
# {'session_index': 137, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Tue', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 138, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C404', 'day': 'Thu', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 139, 'course': 'BBS1014', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 140, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 141, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 142, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 143, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Fri', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 144, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 145, 'course': 'BBS1034', 'lecturer': 'ASST. PROF. DR. SATHIYARAJ THAMBIAYYA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 146, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 147, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 148, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 149, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 150, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 151, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 20, 'end_hour': 21}
# {'session_index': 152, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 153, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 154, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 155, 'course': 'BBS1063', 'lecturer': 'ASST. PROF. DR. KALPANA MUTHUSAMY', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 156, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Tue', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 157, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 158, 'course': 'BEA1015', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 159, 'course': 'BEA1023', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 160, 'course': 'BEA1033', 'lecturer': 'INTAN LIANA SAMSUDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 161, 'course': 'BEA1043', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 162, 'course': 'BEA1043', 'lecturer': 'NICHOLAS NG KHOON WU', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 9, 'end_hour': 10}
# {'session_index': 163, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 164, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 165, 'course': 'BEA1055', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 166, 'course': 'BEA1063', 'lecturer': 'DR. KHOO FONG YI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 167, 'course': 'BEA1073', 'lecturer': 'BAKHTIAR AMIR', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 168, 'course': 'BEA1083', 'lecturer': 'TS. MALIZA ISMAIL JAMAIL', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 169, 'course': 'BEA1083', 'lecturer': 'TS. MALIZA ISMAIL JAMAIL', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 170, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 171, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 172, 'course': 'BEA2018', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 173, 'course': 'BEA2023', 'lecturer': 'INTAN LIANA SAMSUDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 174, 'course': 'BEA2033', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 175, 'course': 'BEA2043', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 176, 'course': 'BEA2053', 'lecturer': 'TS. CHAN CHIEW CHUEN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 177, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 178, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 179, 'course': 'BEA2068', 'lecturer': 'IDA MARLINA MAZLAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 180, 'course': 'BEA2073', 'lecturer': 'DR. KHOO FONG YI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 181, 'course': 'BEA2083', 'lecturer': 'ASSISTANT PROFESSOR DR. ZHAO SHENGHUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 182, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Tue', 'start_hour': 18, 'end_hour': 21}
# {'session_index': 183, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 184, 'course': 'BEA3018', 'lecturer': 'YUSRA ZULKIFLI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 185, 'course': 'BEA3023', 'lecturer': 'PROFESSOR DR. NANGKULA UTABERTA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 186, 'course': 'BEA3034', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 187, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 188, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 189, 'course': 'BEA30410', 'lecturer': 'CHEAH EE VON', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 190, 'course': 'BEA3066', 'lecturer': 'NURHAYATI ZULKEPLY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 191, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 192, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 193, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 194, 'course': 'BEE1023', 'lecturer': 'ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 195, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 196, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Wed', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 197, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 198, 'course': 'BEI1055', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 199, 'course': 'BEI1063', 'lecturer': 'LEONG YEAN TUCK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Mon', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 200, 'course': 'BEI1063', 'lecturer': 'LEONG YEAN TUCK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Thu', 'start_hour': 8, 'end_hour': 9}
# {'session_index': 201, 'course': 'BEI1073', 'lecturer': 'RAJA HALIZA SUHAILA BTE RAJA ABD HAMID', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Thu', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 202, 'course': 'BEI1083', 'lecturer': 'NURUL ANIDA MOHAMAD', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C314', 'day': 'Wed', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 203, 'course': 'BEI2017', 'lecturer': 'DR. WONG LEONG YEE', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 17, 'end_hour': 20}
# ...
# {'session_index': 801, 'course': 'OP323', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 802, 'course': 'OP324', 'lecturer': 'DR. MUHAMMAD IKMAL MOHAMMAD KAMIL', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 803, 'course': 'OP324', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Wed', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 804, 'course': 'OP325', 'lecturer': 'AL KHUSAIRI AIDID ABU ASMARA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 805, 'course': 'OP325', 'lecturer': 'AL KHUSAIRI AIDID ABU ASMARA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 11, 'end_hour': 13}
# {'session_index': 806, 'course': 'OP413', 'lecturer': 'ASSISTANT PROFESSOR DR. TEOH SWEE CHAI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 807, 'course': 'OP414', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Thu', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 808, 'course': 'OP415', 'lecturer': 'ASSOC. PROF. DR. LILI ASMA', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 809, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Tue', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 810, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Thu', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 811, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C3M05', 'day': 'Fri', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 812, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'FOSSLA PHD MEETING ROOM', 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 813, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 814, 'course': 'OP416', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'GROUP THERAPY ROOM', 'day': 'Fri', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 815, 'course': 'OP422', 'lecturer': 'NOORSHAZANA MAT REJAB @ MD REJAB', 'category': 'PBL', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 816, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C404', 'day': 'Mon', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 817, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 8, 'end_hour': 11}
# {'session_index': 818, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Thu', 'start_hour': 8, 'end_hour': 10}
# {'session_index': 819, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 820, 'course': 'OP424', 'lecturer': "ASST. PROF. DR. 'ADILAH MOHD ALI", 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 16, 'end_hour': 17}
# {'session_index': 821, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Thu', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 822, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 13, 'end_hour': 14}
# {'session_index': 823, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 16, 'end_hour': 19}
# {'session_index': 824, 'course': 'PST1014B', 'lecturer': 'ASST. PROF. DR. ZAIDA MUSTAFA', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 11, 'end_hour': 12}
# {'session_index': 825, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 826, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'C3M05', 'day': 'Thu', 'start_hour': 14, 'end_hour': 15}
# {'session_index': 827, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M05', 'day': 'Mon', 'start_hour': 15, 'end_hour': 18}
# {'session_index': 828, 'course': 'PST1024B', 'lecturer': 'ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 829, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 16, 'end_hour': 18}
# {'session_index': 830, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 831, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 832, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 833, 'course': 'SE004', 'lecturer': 'MARIAL ANNE A/P ANANDAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 834, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 13, 'end_hour': 15}
# {'session_index': 835, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 836, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 837, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 838, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 19, 'end_hour': 21}
# {'session_index': 839, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Tue', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 840, 'course': 'SE005', 'lecturer': 'DAPHNE WOON DEIN LUEN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 10, 'end_hour': 12}
# {'session_index': 841, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 15, 'end_hour': 16}
# {'session_index': 842, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Wed', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 843, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 9, 'end_hour': 11}
# {'session_index': 844, 'course': 'SE121', 'lecturer': 'DR. ALADDIN Y.M. ASSAIQELI', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 845, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 846, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C404', 'day': 'Tue', 'start_hour': 12, 'end_hour': 13}
# {'session_index': 847, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'TUTORIAL', 'required_duration': 1, 'assigned_classroom': 'C3M04B', 'day': 'Thu', 'start_hour': 10, 'end_hour': 11}
# {'session_index': 848, 'course': 'SE123', 'lecturer': 'ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'C3M04B', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 849, 'course': 'SM101', 'lecturer': 'ASST. PROF. DR. ALWYN LAU WING WANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 850, 'course': 'SM101', 'lecturer': 'ASST. PROF. DR. ALWYN LAU WING WANG', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 11, 'end_hour': 14}
# {'session_index': 851, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': None, 'day': 'Wed', 'start_hour': 18, 'end_hour': 19}
# {'session_index': 852, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 15, 'end_hour': 17}
# {'session_index': 853, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': None, 'day': 'Mon', 'start_hour': 17, 'end_hour': 18}
# {'session_index': 854, 'course': 'SM106', 'lecturer': 'MD SHAM SAMAD', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 12, 'end_hour': 14}
# {'session_index': 855, 'course': 'SM114', 'lecturer': 'MOHD FARIZI JAMALUDDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Fri', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 856, 'course': 'SM114', 'lecturer': 'MOHD FARIZI JAMALUDDIN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': None, 'day': 'Thu', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 857, 'course': 'SM115', 'lecturer': 'ASST. PROF. DR. VIMALA A/P GOVINDASAMY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 858, 'course': 'SM115', 'lecturer': 'ASST. PROF. DR. VIMALA A/P GOVINDASAMY', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Mon', 'start_hour': 13, 'end_hour': 16}
# {'session_index': 859, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 14, 'end_hour': 16}
# {'session_index': 860, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Wed', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 861, 'course': 'SP110', 'lecturer': 'ASSISTANT PROFESSOR DR. SAEID MOTEVALLI', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Fri', 'start_hour': 10, 'end_hour': 13}
# {'session_index': 862, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Fri', 'start_hour': 14, 'end_hour': 17}
# {'session_index': 863, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'TUTORIAL', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Mon', 'start_hour': 18, 'end_hour': 20}
# {'session_index': 864, 'course': 'SP121', 'lecturer': 'DR. TAN LI HUAN', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 17, 'end_hour': 20}
# {'session_index': 865, 'course': 'SP206', 'lecturer': "NURUL HIDAYAH BT MOHD SA'AT", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Mon', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 866, 'course': 'SP206', 'lecturer': "NURUL HIDAYAH BT MOHD SA'AT", 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 12, 'end_hour': 15}
# {'session_index': 867, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 2, 'assigned_classroom': 'C314', 'day': 'Tue', 'start_hour': 17, 'end_hour': 19}
# {'session_index': 868, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 3, 'assigned_classroom': 'ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY', 'day': 'Tue', 'start_hour': 9, 'end_hour': 12}
# {'session_index': 869, 'course': 'SP208', 'lecturer': 'ARMAN IMRAN ASHOK', 'category': 'LECTURE', 'required_duration': 1, 'assigned_classroom': 'MPH - GBS', 'day': 'Thu', 'start_hour': 18, 'end_hour': 19}

# %%
import pandas as pd
import numpy as np
import random
import math

# -------------------------------
# 전처리된 offer 데이터 (df_sessions)와 classroom 데이터가 이미 로드되어 있다고 가정
# df_sessions: offer 데이터 전처리 후, 세션 분할 및 인덱스 재설정된 DataFrame
# classroom: 전처리된 classroom DataFrame
# days: 월~금, 시간 슬롯: 08시 ~ 21시 (1시간 단위)
# -------------------------------
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

def get_valid_start_hours(duration_hours):
    """
    주어진 세션의 지속시간(duration_hours)에 대해,
    시작시간(start_hour) + duration_hours가 21시 이하가 되는 유효한 시작시간 리스트 반환
    """
    return [h for h in range(8, 22) if h + duration_hours <= 21]

# -------------------------------
# 기존 랜덤 서치에서 사용한 score_schedule 함수 (패널티 기반 평가)
# -------------------------------
def score_schedule(schedule, df_sessions, classroom):
    """
    스케줄의 제약 위반에 대해 페널티를 부여합니다.
    
    제약 조건:
      - 강의실이나 시작시간 미할당: +5
      - 시간대 범위 (08~21시) 벗어나면: +3
      - 강의실 정보 누락: +3
      - 강의실 용량 부족: +3
      - Lab 강의인데 Lab 강의실이 아니면: +3
      - 동일 요일 내 동일 강의실 또는 동일 강사의 시간 충돌: 각 충돌 당 +5
    """
    penalty = 0
    n = len(schedule)
    for i in range(n):
        a = schedule[i]
        if a['assigned_classroom'] is None or a['start_hour'] is None:
            penalty += 5
            continue
        if a['start_hour'] < 8 or a['end_hour'] > 21:
            penalty += 3
        cls = classroom[classroom['Resource Code'] == a['assigned_classroom']]
        if cls.empty:
            penalty += 3
        else:
            room_capacity = cls.iloc[0]['Capacity']
            required_capacity = df_sessions.iloc[a['session_index']]['Capacity']
            if room_capacity < required_capacity:
                penalty += 3
            room_cat = cls.iloc[0]['Category'].upper()
            if a['category'].upper() == "LAB" and room_cat != "LAB":
                penalty += 3
        for j in range(i+1, n):
            b = schedule[j]
            if a['day'] != b['day']:
                continue
            if a['assigned_classroom'] == b['assigned_classroom']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 5
            if a['lecturer'] == b['lecturer']:
                if not (a['end_hour'] <= b['start_hour'] or b['end_hour'] <= a['start_hour']):
                    penalty += 5
    return penalty

# -------------------------------
# GA에서 사용할 개별 유전자(세션 배정) 생성 함수
# -------------------------------
def create_gene(i):
    """
    df_sessions의 i번째 세션에 대해, 강의실, 요일, 시작시간을 무작위로 할당한 유전자 생성
    """
    session = df_sessions.iloc[i]
    duration_hours = math.ceil(session['Min Per Session'] / 60)
    
    # 강의실 후보: 용량 조건
    valid_rooms = classroom[classroom['Capacity'] >= session['Capacity']]
    session_cat = session['Category'].upper()
    if session_cat == "LAB":
        valid_rooms = valid_rooms[valid_rooms['Category'].str.upper() == "LAB"]
    else:
        valid_rooms = valid_rooms[valid_rooms['Category'].str.upper().isin(["GENERAL", "LECTURE"])]
    if valid_rooms.empty:
        assigned_room = None
    else:
        assigned_room = random.choice(valid_rooms['Resource Code'].tolist())
    
    assigned_day = random.choice(days)
    valid_hours = get_valid_start_hours(duration_hours)
    if not valid_hours:
        assigned_hour = None
    else:
        assigned_hour = random.choice(valid_hours)
    
    gene = {
        'session_index': i,
        'course': session['CourseCode'],
        'lecturer': session['Lecturer'],
        'category': session['Category'],
        'required_duration': duration_hours,
        'assigned_classroom': assigned_room,
        'day': assigned_day,
        'start_hour': assigned_hour,
        'end_hour': assigned_hour + duration_hours if assigned_hour is not None else None
    }
    return gene

def create_individual():
    """
    모든 세션에 대해 유전자를 생성하여 개체(시간표)를 반환
    """
    return [create_gene(i) for i in range(len(df_sessions))]

# -------------------------------
# 개체 평가 함수: 페널티 기반 평가를 이용해 fitness 계산
# fitness = 1/(1 + penalty) (패널티가 낮을수록 fitness가 높음)
# -------------------------------
def evaluate_individual(individual):
    penalty = score_schedule(individual, df_sessions, classroom)
    fitness = 1 / (1 + penalty)
    return fitness

# -------------------------------
# Tournament selection
# -------------------------------
def tournament_selection(population, fitnesses, tournament_size):
    selected = []
    for _ in range(len(population)):
        tournament_indices = random.sample(range(len(population)), tournament_size)
        best = None
        best_fit = -1
        for idx in tournament_indices:
            if fitnesses[idx] > best_fit:
                best_fit = fitnesses[idx]
                best = population[idx]
        selected.append(best)
    return selected

# -------------------------------
# One-point crossover
# -------------------------------
def crossover(parent1, parent2):
    size = len(parent1)
    if size < 2:
        return parent1, parent2
    point = random.randint(1, size - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

# -------------------------------
# Mutation: 각 유전자에 대해 일정 확률로 재할당
# -------------------------------
def mutate(individual, mutation_rate):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = create_gene(i)
    return individual

# -------------------------------
# GA 파라미터 설정
# -------------------------------
POP_SIZE = 50
NUM_GENERATIONS = 2000
TOURNAMENT_SIZE = 3
CROSSOVER_RATE = 0.8
MUTATION_RATE = 0.1

# -------------------------------
# GA 메인 루프
# -------------------------------
def genetic_algorithm():
    population = [create_individual() for _ in range(POP_SIZE)]
    best_individual = None
    best_fitness = -1
    for gen in range(NUM_GENERATIONS):
        fitnesses = [evaluate_individual(ind) for ind in population]
        # 현재 세대 최고 개체 갱신
        for ind, fit in zip(population, fitnesses):
            if fit > best_fitness:
                best_fitness = fit
                best_individual = ind
        # 선택
        selected = tournament_selection(population, fitnesses, TOURNAMENT_SIZE)
        # 다음 세대 생성: 교차 및 돌연변이 적용
        next_population = []
        while len(next_population) < POP_SIZE:
            p1 = random.choice(selected)
            p2 = random.choice(selected)
            if random.random() < CROSSOVER_RATE:
                child1, child2 = crossover(p1, p2)
            else:
                child1, child2 = p1.copy(), p2.copy()
            child1 = mutate(child1, MUTATION_RATE)
            child2 = mutate(child2, MUTATION_RATE)
            next_population.append(child1)
            if len(next_population) < POP_SIZE:
                next_population.append(child2)
        population = next_population
        if gen % 10 == 0:
            current_penalty = score_schedule(best_individual, df_sessions, classroom)
            print(f"Generation {gen}: Best fitness = {best_fitness:.4f}, Penalty = {current_penalty}")
    return best_individual, best_fitness

# -------------------------------
# GA 실행
# -------------------------------
best_individual, best_fit = genetic_algorithm()
print("\n최적 개체 (Genetic Algorithm 결과):")
print("Best fitness:", best_fit)
print("Best individual penalty:", 1/best_fit - 1)

# -------------------------------
# 시간표 출력 함수 (이전의 print_timetable 함수 활용)
# -------------------------------
def print_timetable(schedule):
    days_order = ["Mon", "Tue", "Wed", "Thu", "Fri"]
    for day in days_order:
        print(f"----- {day} -----")
        day_assignments = [a for a in schedule if a['day'] == day]
        day_assignments.sort(key=lambda x: x['start_hour'] if x['start_hour'] is not None else 99)
        if not day_assignments:
            print("No sessions scheduled.")
        else:
            for a in day_assignments:
                print(f"{a['start_hour']:02d}:00 ~ {a['end_hour']:02d}:00 | Course: {a['course']} ({a['category']}) | Room: {a['assigned_classroom']} | Lecturer: {a['lecturer']}")
        print()

print("\n최적 시간표 (Genetic Algorithm 결과):")
print_timetable(best_individual)
# Out:
# Generation 0: Best fitness = 0.0001, Penalty = 15650
# Generation 10: Best fitness = 0.0001, Penalty = 14480
# Generation 20: Best fitness = 0.0001, Penalty = 14110
# Generation 30: Best fitness = 0.0001, Penalty = 14095
# Generation 40: Best fitness = 0.0001, Penalty = 13890
# Generation 50: Best fitness = 0.0001, Penalty = 13890
# Generation 60: Best fitness = 0.0001, Penalty = 13890
# Generation 70: Best fitness = 0.0001, Penalty = 13715
# Generation 80: Best fitness = 0.0001, Penalty = 13715
# Generation 90: Best fitness = 0.0001, Penalty = 13715
# Generation 100: Best fitness = 0.0001, Penalty = 13715
# Generation 110: Best fitness = 0.0001, Penalty = 13715
# Generation 120: Best fitness = 0.0001, Penalty = 13715
# Generation 130: Best fitness = 0.0001, Penalty = 13715
# Generation 140: Best fitness = 0.0001, Penalty = 13715
# Generation 150: Best fitness = 0.0001, Penalty = 13715
# Generation 160: Best fitness = 0.0001, Penalty = 13715
# Generation 170: Best fitness = 0.0001, Penalty = 13715
# Generation 180: Best fitness = 0.0001, Penalty = 13715
# Generation 190: Best fitness = 0.0001, Penalty = 13715
# Generation 200: Best fitness = 0.0001, Penalty = 13715
# Generation 210: Best fitness = 0.0001, Penalty = 13715
# Generation 220: Best fitness = 0.0001, Penalty = 13715
# Generation 230: Best fitness = 0.0001, Penalty = 13715
# Generation 240: Best fitness = 0.0001, Penalty = 13715
# Generation 250: Best fitness = 0.0001, Penalty = 13715
# Generation 260: Best fitness = 0.0001, Penalty = 13715
# Generation 270: Best fitness = 0.0001, Penalty = 13715
# Generation 280: Best fitness = 0.0001, Penalty = 13715
# Generation 290: Best fitness = 0.0001, Penalty = 13520
# Generation 300: Best fitness = 0.0001, Penalty = 13520
# Generation 310: Best fitness = 0.0001, Penalty = 13520
# Generation 320: Best fitness = 0.0001, Penalty = 13520
# Generation 330: Best fitness = 0.0001, Penalty = 13520
# Generation 340: Best fitness = 0.0001, Penalty = 13520
# Generation 350: Best fitness = 0.0001, Penalty = 13520
# Generation 360: Best fitness = 0.0001, Penalty = 13520
# Generation 370: Best fitness = 0.0001, Penalty = 13520
# Generation 380: Best fitness = 0.0001, Penalty = 13520
# Generation 390: Best fitness = 0.0001, Penalty = 13520
# Generation 400: Best fitness = 0.0001, Penalty = 13520
# Generation 410: Best fitness = 0.0001, Penalty = 13520
# Generation 420: Best fitness = 0.0001, Penalty = 13520
# Generation 430: Best fitness = 0.0001, Penalty = 13520
# Generation 440: Best fitness = 0.0001, Penalty = 13520
# Generation 450: Best fitness = 0.0001, Penalty = 13520
# Generation 460: Best fitness = 0.0001, Penalty = 13520
# Generation 470: Best fitness = 0.0001, Penalty = 13520
# Generation 480: Best fitness = 0.0001, Penalty = 13520
# Generation 490: Best fitness = 0.0001, Penalty = 13520
# Generation 500: Best fitness = 0.0001, Penalty = 13520
# Generation 510: Best fitness = 0.0001, Penalty = 13520
# Generation 520: Best fitness = 0.0001, Penalty = 13520
# Generation 530: Best fitness = 0.0001, Penalty = 13520

# %%
# best_schedule은 이미 랜덤 서치를 통해 구한 최적의 시간표 리스트라고 가정합니다.
# 각 항목은 { 'session_index', 'course', 'lecturer', 'category', 'required_duration',
#               'assigned_classroom', 'day', 'start_hour', 'end_hour' } 의 딕셔너리입니다.

def print_timetable(schedule):
    # 요일별로 그룹화
    days_order = ["Mon", "Tue", "Wed", "Thu", "Fri"]
    for day in days_order:
        print(f"----- {day} -----")
        # 해당 요일의 배정된 세션 필터링 후 시작시간 순으로 정렬
        day_assignments = [a for a in schedule if a['day'] == day]
        day_assignments.sort(key=lambda x: x['start_hour'] if x['start_hour'] is not None else 99)
        
        if not day_assignments:
            print("No sessions scheduled.")
        else:
            for a in day_assignments:
                # 강의실, 강의, 강사, 시간대, 세션 정보 출력
                print(f"{a['start_hour']:02d}:00 ~ {a['end_hour']:02d}:00 | Course: {a['course']} ({a['category']}) | Room: {a['assigned_classroom']} | Lecturer: {a['lecturer']}")
        print()

# 최적의 시간표 출력 (랜덤 서치 이후)
print_timetable(best_schedule)
# Out:
# ----- Mon -----
# 08:00 ~ 09:00 | Course: BAB1053 (LECTURE) | Room: C314 | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 08:00 ~ 09:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 08:00 ~ 11:00 | Course: BHH1113 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MARWA REFAAT MAHMOUD AHMED
# 08:00 ~ 11:00 | Course: BIC1144T (LECTURE) | Room: MPH - GBS | Lecturer: TBA5
# 08:00 ~ 09:00 | Course: BP263 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SASIKALA CHINNAPPAN
# 08:00 ~ 09:00 | Course: BP373 (TUTORIAL) | Room: MPH - GBS | Lecturer: SABREEN YOUSIF MOHAMMED ALHASSAN NASR
# 08:00 ~ 09:00 | Course: BPC3142 (TUTORIAL) | Room: C314 | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 08:00 ~ 10:00 | Course: CET09 (LECTURE) | Room: MPH - GBS | Lecturer: JONATHAN A/L ABISHEGAM
# 08:00 ~ 10:00 | Course: DEX1034 (ART) | Room: C314 | Lecturer: TS. AMAR RIDZUAN ABD HAMID
# 08:00 ~ 11:00 | Course: DFS121 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ELNAZ ROSTAMIGHARAGOZLOO
# 08:00 ~ 10:00 | Course: FBF1124 (LECTURE) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 08:00 ~ 11:00 | Course: FSL1243 (LECTURE) | Room: None | Lecturer: MOHAMAD BILAL ALI
# 08:00 ~ 11:00 | Course: MB110 (LAB) | Room: BIOCHEM | Lecturer: DR. LAU YIN YIN
# 08:00 ~ 11:00 | Course: MEA2018 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. AR. CHIA LIN LIN
# 08:00 ~ 10:00 | Course: MPU3232 (LECTURE) | Room: None | Lecturer: NORFAIZADATUL AKMA MOHAMAD MASWAN
# 08:00 ~ 10:00 | Course: OP324 (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 08:00 ~ 11:00 | Course: OP416 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 09:00 ~ 12:00 | Course: AR453 (LECTURE) | Room: MPH - GBS | Lecturer: NURHAYATI ZULKEPLY
# 09:00 ~ 10:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 09:00 ~ 11:00 | Course: BBS1014 (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 09:00 ~ 12:00 | Course: BEQ1093 (LECTURE) | Room: MPH - GBS | Lecturer: TS. IRNA NURSYAFINA ROSDI
# 09:00 ~ 12:00 | Course: BEQ2053 (LECTURE) | Room: C404 | Lecturer: DR. ZAIRRA MAT JUSOH
# 09:00 ~ 10:00 | Course: BIB3103 (TUTORIAL) | Room: MPH - GBS | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 09:00 ~ 10:00 | Course: BIC1144T (LECTURE) | Room: MPH - GBS | Lecturer: TBA5
# 09:00 ~ 10:00 | Course: BP267 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 09:00 ~ 10:00 | Course: BPC1112 (LECTURE) | Room: None | Lecturer: PROFESSOR DR. SAAD TAYYAB
# 09:00 ~ 10:00 | Course: BPC2094 (TUTORIAL) | Room: C3M04B | Lecturer: DR. KUSHAGRA KHANNA
# 09:00 ~ 11:00 | Course: CET10 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 09:00 ~ 12:00 | Course: MEA2034 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: PROF. DR. MOHD. TAJUDDIN MOHD. RASDI
# 09:00 ~ 10:00 | Course: SE123 (TUTORIAL) | Room: C3M05 | Lecturer: ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG
# 10:00 ~ 11:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 10:00 ~ 11:00 | Course: BBS1014 (TUTORIAL) | Room: C314 | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 10:00 ~ 13:00 | Course: BEI2067 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 10:00 ~ 11:00 | Course: BEX1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: FETBE TBA1
# 10:00 ~ 11:00 | Course: BP314 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. CHEONG KOK WHYE
# 10:00 ~ 11:00 | Course: BP493 (LECTURE) | Room: MPH - GBS | Lecturer: SABREEN YOUSIF MOHAMMED ALHASSAN NASR
# 10:00 ~ 11:00 | Course: BPC2104 (LECTURE) | Room: C314 | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 10:00 ~ 12:00 | Course: CET10 (LECTURE) | Room: C314 | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 10:00 ~ 13:00 | Course: DA101 (LECTURE) | Room: C3M04B | Lecturer: IVAN LAM WAI HOE
# 10:00 ~ 12:00 | Course: FAS1053 (LAB) | Room: RESEARCHLB | Lecturer: FARHANA ABDUL BARRI
# 10:00 ~ 11:00 | Course: FAS1053 (LECTURE) | Room: None | Lecturer: FARHANA ABDUL BARRI
# 10:00 ~ 12:00 | Course: FBF1384 (LECTURE) | Room: MPH - GBS | Lecturer: THILAGAVATHI A/P MUTTU
# 10:00 ~ 13:00 | Course: FDD1333 (LECTURE) | Room: MPH - GBS | Lecturer: ELNAZ ROSTAMIGHARAGOZLOO
# 10:00 ~ 12:00 | Course: MPP1074 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 10:00 ~ 12:00 | Course: OP221 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 10:00 ~ 12:00 | Course: OP314 (LECTURE) | Room: C314 | Lecturer: DR. MUHAMMAD IKMAL MOHAMMAD KAMIL
# 10:00 ~ 12:00 | Course: SE004 (TUTORIAL) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 10:00 ~ 13:00 | Course: SP121 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. TAN LI HUAN
# 11:00 ~ 14:00 | Course: AB516 (LECTURE) | Room: MPH - GBS | Lecturer: LIM KER CHWING
# 11:00 ~ 14:00 | Course: BAN1042 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. NURLIYANA ABDUL RAZAK
# 11:00 ~ 14:00 | Course: BEA2023 (LECTURE) | Room: MPH - GBS | Lecturer: INTAN LIANA SAMSUDIN
# 11:00 ~ 13:00 | Course: BEE1023 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN
# 11:00 ~ 14:00 | Course: BEI4043 (LECTURE) | Room: MPH - GBS | Lecturer: NOR ZALINA MD NOR
# 11:00 ~ 14:00 | Course: BHA1043 (LECTURE) | Room: C3M05 | Lecturer: RIZA MUNIRA SHAMSUDIN
# 11:00 ~ 13:00 | Course: BIC1233 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 11:00 ~ 12:00 | Course: BP112 (LECTURE) | Room: None | Lecturer: PROFESSOR DR. SAAD TAYYAB
# 11:00 ~ 12:00 | Course: BPC1063 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. RAVISHANKAR RAM MANI
# 11:00 ~ 12:00 | Course: BPC1103 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. LAU KIA KIAN
# 11:00 ~ 12:00 | Course: BPC1112 (LECTURE) | Room: None | Lecturer: PROFESSOR DR. SAAD TAYYAB
# 11:00 ~ 13:00 | Course: CD102 (LECTURE) | Room: C314 | Lecturer: SALEH ABDULALEM ALI MOHAMMED
# 11:00 ~ 13:00 | Course: CET07 (LECTURE) | Room: C314 | Lecturer: DR. FATEMEH AMIRI
# 11:00 ~ 13:00 | Course: CET09 (LECTURE) | Room: C314 | Lecturer: JONATHAN A/L ABISHEGAM
# 11:00 ~ 13:00 | Course: CET10 (LECTURE) | Room: MPH - GBS | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 11:00 ~ 13:00 | Course: CET10 (LECTURE) | Room: C3M04B | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 11:00 ~ 13:00 | Course: FAS1053 (LAB) | Room: POWER LAB | Lecturer: FARHANA ABDUL BARRI
# 11:00 ~ 12:00 | Course: FBF1074 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 11:00 ~ 12:00 | Course: FBF1384 (LECTURE) | Room: MPH - GBS | Lecturer: THILAGAVATHI A/P MUTTU
# 11:00 ~ 12:00 | Course: FBF1404 (TUTORIAL) | Room: MPH - GBS | Lecturer: AZMIR ISMAIL
# 12:00 ~ 14:00 | Course: BAB1044 (LECTURE) | Room: MPH - GBS | Lecturer: DR. LAU YIN YIN
# 12:00 ~ 13:00 | Course: BAB1053 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 12:00 ~ 13:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 12:00 ~ 15:00 | Course: BEA1015 (LECTURE) | Room: None | Lecturer: NICHOLAS NG KHOON WU
# 12:00 ~ 15:00 | Course: BEA2073 (LECTURE) | Room: MPH - GBS | Lecturer: DR. KHOO FONG YI
# 12:00 ~ 13:00 | Course: BP132 (TUTORIAL) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 12:00 ~ 13:00 | Course: BP314 (TUTORIAL) | Room: None | Lecturer: ASST. PROF. DR. CHEONG KOK WHYE
# 12:00 ~ 13:00 | Course: BPC3123 (TUTORIAL) | Room: C404 | Lecturer: DR. LAU KIA KIAN
# 12:00 ~ 14:00 | Course: CET04 (LECTURE) | Room: None | Lecturer: ARVIND A/L DAVID
# 12:00 ~ 14:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 12:00 ~ 14:00 | Course: CET07 (LECTURE) | Room: C314 | Lecturer: DR. FATEMEH AMIRI
# 12:00 ~ 15:00 | Course: FAB1013 (LECTURE) | Room: MPH - GBS | Lecturer: DR. YUVANESWARI A/P CHANDRAMOULEE SWARAN
# 12:00 ~ 15:00 | Course: MPP1074 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 12:00 ~ 14:00 | Course: OP114 (LECTURE) | Room: C3M04B | Lecturer: DR. SANGAR A/L SUBRAMANIAM
# 12:00 ~ 15:00 | Course: OP311 (LECTURE) | Room: MPH - GBS | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 12:00 ~ 14:00 | Course: OP314 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 12:00 ~ 15:00 | Course: OP321 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: IRFAH AMIRIN
# 13:00 ~ 14:00 | Course: BAN1023 (LECTURE) | Room: C314 | Lecturer: DR. SHASHIKALA SIVAPATHY
# 13:00 ~ 14:00 | Course: BAN1042 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: DR. NURLIYANA ABDUL RAZAK
# 13:00 ~ 15:00 | Course: BEE1023 (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN
# 13:00 ~ 15:00 | Course: BEX1013 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. TENG KAH HOU
# 13:00 ~ 14:00 | Course: BIC1214 (LAB) | Room: C311 PHYSICS LAB | Lecturer: TS. DR. SUKHMINDER KAUR
# 13:00 ~ 15:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 13:00 ~ 15:00 | Course: DBB1083 (LECTURE) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 13:00 ~ 14:00 | Course: MPU3221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 13:00 ~ 16:00 | Course: OP321 (LECTURE) | Room: C404 | Lecturer: NORFATNIN AZMIN
# 14:00 ~ 16:00 | Course: AB516 (LECTURE) | Room: MPH - GBS | Lecturer: LIM KER CHWING
# 14:00 ~ 17:00 | Course: BEA3066 (LECTURE) | Room: MPH - GBS | Lecturer: NURHAYATI ZULKEPLY
# 14:00 ~ 16:00 | Course: BEQ2112 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. TS. SR. DR. NADZIRAH ZAINORDIN
# 14:00 ~ 15:00 | Course: BEX1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. TS. DR. YU LIH JIUN
# 14:00 ~ 15:00 | Course: BP254 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 14:00 ~ 15:00 | Course: BP265 (TUTORIAL) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 14:00 ~ 15:00 | Course: BP314 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. CHEONG KOK WHYE
# 14:00 ~ 15:00 | Course: BP493 (LECTURE) | Room: MPH - GBS | Lecturer: SABREEN YOUSIF MOHAMMED ALHASSAN NASR
# 14:00 ~ 15:00 | Course: BPC3083 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. LOW MAY LEE
# 14:00 ~ 15:00 | Course: BPC3093 (LECTURE) | Room: C3M05 | Lecturer: AUDREY KOW SIEW FOONG
# 14:00 ~ 17:00 | Course: BSE1033 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASST. PROF. DR. KU FARIDAH KU IBRAHIM
# 14:00 ~ 16:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 14:00 ~ 15:00 | Course: FBF1074 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 14:00 ~ 15:00 | Course: FBF1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 14:00 ~ 16:00 | Course: MPP1074 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 14:00 ~ 17:00 | Course: OP214 (LECTURE) | Room: C3M04B | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 14:00 ~ 15:00 | Course: OP424 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 14:00 ~ 17:00 | Course: PST1024B (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH
# 14:00 ~ 15:00 | Course: SM106 (LECTURE) | Room: None | Lecturer: MD SHAM SAMAD
# 15:00 ~ 18:00 | Course: AB533 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 15:00 ~ 18:00 | Course: AB633 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: TAN HAN LEONG
# 15:00 ~ 16:00 | Course: BAC1064 (LECTURE) | Room: C3M05 | Lecturer: DR. REVATHI A/P RAJAN
# 15:00 ~ 18:00 | Course: BEA2018 (LECTURE) | Room: MPH - GBS | Lecturer: TS. CHAN CHIEW CHUEN
# 15:00 ~ 18:00 | Course: BEQ3053 (LECTURE) | Room: C3M05 | Lecturer: DR. NORSHAKILA MUHAMAD RAWAI
# 15:00 ~ 18:00 | Course: BHH1043 (LECTURE) | Room: MPH - GBS | Lecturer: NUR-IMAN HASHIM
# 15:00 ~ 16:00 | Course: BIB3103 (TUTORIAL) | Room: MPH - GBS | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 15:00 ~ 16:00 | Course: BIC1123 (LECTURE) | Room: None | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 15:00 ~ 16:00 | Course: BP497 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 15:00 ~ 18:00 | Course: BSE1013 (LECTURE) | Room: MPH - GBS | Lecturer: ASSOC. PROF. DR. AZHAR MD ADNAN
# 15:00 ~ 17:00 | Course: CET10 (LECTURE) | Room: C314 | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 15:00 ~ 17:00 | Course: CET10 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 15:00 ~ 18:00 | Course: DFS113 (LECTURE) | Room: C314 | Lecturer: NABIELA AMINUDIN
# 15:00 ~ 16:00 | Course: FBF1374 (LECTURE) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 15:00 ~ 18:00 | Course: OP122 (LECTURE) | Room: MPH - GBS | Lecturer: SHARMANEE A/P THIAGARAJAH
# 15:00 ~ 18:00 | Course: OP212 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ESTHER LAU SIEW SIENG
# 15:00 ~ 17:00 | Course: SE005 (TUTORIAL) | Room: MPH - GBS | Lecturer: DAPHNE WOON DEIN LUEN
# 15:00 ~ 18:00 | Course: SE123 (LECTURE) | Room: C3M05 | Lecturer: ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG
# 16:00 ~ 19:00 | Course: AB516 (LECTURE) | Room: MPH - GBS | Lecturer: LIM KER CHWING
# 16:00 ~ 17:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 16:00 ~ 19:00 | Course: BEQ1023 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. ZAIRRA MAT JUSOH
# 16:00 ~ 17:00 | Course: BP372 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 16:00 ~ 17:00 | Course: BP495 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 16:00 ~ 18:00 | Course: CD211 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. TS. DR. SHAYLA ISLAM
# 16:00 ~ 19:00 | Course: DFS122 (LECTURE) | Room: C3M05 | Lecturer: MUHAMMAD ARIFF NORDIN
# 16:00 ~ 17:00 | Course: FBF1173 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. USMAN AKBAR
# 16:00 ~ 18:00 | Course: MPU3232 (LECTURE) | Room: None | Lecturer: NORFAIZADATUL AKMA MOHAMAD MASWAN
# 16:00 ~ 18:00 | Course: OP312 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: NOORSHAZANA MAT REJAB @ MD REJAB
# 16:00 ~ 17:00 | Course: SE121 (LECTURE) | Room: MPH - GBS | Lecturer: DR. ALADDIN Y.M. ASSAIQELI
# 17:00 ~ 18:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 17:00 ~ 18:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: THILAGAVATHI A/P MUTTU
# 17:00 ~ 18:00 | Course: BBM1073 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NURKHALIDA MAKMOR
# 17:00 ~ 20:00 | Course: BEA2033 (LECTURE) | Room: MPH - GBS | Lecturer: NURHAYATI ZULKEPLY
# 17:00 ~ 20:00 | Course: BEI2017 (LECTURE) | Room: MPH - GBS | Lecturer: DR. WONG LEONG YEE
# 17:00 ~ 20:00 | Course: BEI2067 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 17:00 ~ 20:00 | Course: BEI2083 (LECTURE) | Room: MPH - GBS | Lecturer: NOR ZALINA MD NOR
# 17:00 ~ 20:00 | Course: BEQ1033 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: NURINA NAWI
# 17:00 ~ 20:00 | Course: BHH1073 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. MOHAMAD FADZLY CHE OMAR
# 17:00 ~ 20:00 | Course: BHH1073 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. MOHAMAD FADZLY CHE OMAR
# 17:00 ~ 19:00 | Course: CET08 (LECTURE) | Room: C314 | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 17:00 ~ 19:00 | Course: CET09 (LECTURE) | Room: C314 | Lecturer: JONATHAN A/L ABISHEGAM
# 17:00 ~ 18:00 | Course: FAS1034 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MICHELLE TEO YEE MUN
# 17:00 ~ 19:00 | Course: FAS1044 (LECTURE) | Room: C404 | Lecturer: KAVITA A/P CHIRARA
# 17:00 ~ 20:00 | Course: MEA2023 (LECTURE) | Room: C3M05 | Lecturer: AR. NORIZAN DAUD
# 17:00 ~ 19:00 | Course: OP315 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 17:00 ~ 19:00 | Course: SE004 (TUTORIAL) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 18:00 ~ 20:00 | Course: BAN1023 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: DR. SHASHIKALA SIVAPATHY
# 18:00 ~ 20:00 | Course: BBA2033 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN
# 18:00 ~ 20:00 | Course: BBB1023 (LECTURE) | Room: None | Lecturer: DR. WONG HOONG SANG
# 18:00 ~ 21:00 | Course: BEA1043 (LECTURE) | Room: MPH - GBS | Lecturer: NICHOLAS NG KHOON WU
# 18:00 ~ 21:00 | Course: BEA3018 (LECTURE) | Room: C404 | Lecturer: YUSRA ZULKIFLI
# 18:00 ~ 21:00 | Course: BEQ2043 (LECTURE) | Room: C3M05 | Lecturer: TS. IRNA NURSYAFINA ROSDI
# 18:00 ~ 19:00 | Course: BEX1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. JONATHAN YONG CHUNG EE
# 18:00 ~ 19:00 | Course: BEX1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: SHAHID MANZOOR
# 18:00 ~ 19:00 | Course: BIC1214 (LECTURE) | Room: MPH - GBS | Lecturer: TS. DR. SUKHMINDER KAUR
# 18:00 ~ 19:00 | Course: BP266 (LECTURE) | Room: MPH - GBS | Lecturer: SABREEN YOUSIF MOHAMMED ALHASSAN NASR
# 18:00 ~ 19:00 | Course: BP364 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 18:00 ~ 19:00 | Course: BP381 (LECTURE) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 18:00 ~ 19:00 | Course: CD211 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. TS. DR. SHAYLA ISLAM
# 18:00 ~ 20:00 | Course: CET07 (LECTURE) | Room: C314 | Lecturer: DR. FATEMEH AMIRI
# 18:00 ~ 21:00 | Course: FAS1014 (LAB) | Room: C LAB C | Lecturer: ASST. PROF. ALICE PHUA CHOON YEN
# 18:00 ~ 19:00 | Course: FBF1153 (TUTORIAL) | Room: MPH - GBS | Lecturer: SALEH ABDULALEM ALI MOHAMMED
# 18:00 ~ 19:00 | Course: MPU2221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 18:00 ~ 21:00 | Course: OP111 (LECTURE) | Room: C3M04B | Lecturer: PAVALAMALAR A/P M. RAJALINGAM
# 18:00 ~ 21:00 | Course: OP221 (LECTURE) | Room: C3M04B | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 18:00 ~ 20:00 | Course: SE005 (TUTORIAL) | Room: MPH - GBS | Lecturer: DAPHNE WOON DEIN LUEN
# 19:00 ~ 20:00 | Course: BBA2223 (TUTORIAL) | Room: MPH - GBS | Lecturer: SHAKERIN ISMAIL
# 19:00 ~ 20:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 19:00 ~ 21:00 | Course: BEA2068 (LECTURE) | Room: MPH - GBS | Lecturer: IDA MARLINA MAZLAN
# 19:00 ~ 20:00 | Course: BPC1073 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. RAVISHANKAR RAM MANI
# 19:00 ~ 20:00 | Course: BPC3123 (TUTORIAL) | Room: C404 | Lecturer: DR. LAU KIA KIAN
# 19:00 ~ 21:00 | Course: DBA1023 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MAHALAKSHMI A/P SUPPIAH
# 19:00 ~ 20:00 | Course: FBF1364 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
# 19:00 ~ 20:00 | Course: FBF1374 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 19:00 ~ 20:00 | Course: FSL1204 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ALI KHODI
# 19:00 ~ 21:00 | Course: OP313 (LAB) | Room: C LAB A | Lecturer: ESTHER LAU SIEW SIENG
# 20:00 ~ 21:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 20:00 ~ 21:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 20:00 ~ 21:00 | Course: BP496 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 20:00 ~ 21:00 | Course: BPC2104 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 20:00 ~ 21:00 | Course: BPC3103 (LECTURE) | Room: C3M04B | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 20:00 ~ 21:00 | Course: BPC3123 (LECTURE) | Room: C404 | Lecturer: DR. LAU KIA KIAN
#
# ----- Tue -----
# 08:00 ~ 11:00 | Course: AR873 (LECTURE) | Room: MPH - GBS | Lecturer: CHEAH EE VON
# 08:00 ~ 11:00 | Course: BAN1054 (LAB) | Room: None | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 08:00 ~ 09:00 | Course: BBA1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD
# 08:00 ~ 10:00 | Course: BBS1034 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 08:00 ~ 11:00 | Course: BEQ4053 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: TS. SR KHOO SUI LAI
# 08:00 ~ 11:00 | Course: BFD203 (LECTURE) | Room: C3M04B | Lecturer: ZAREENA TAJUL MUHAMMAD MAJIDI
# 08:00 ~ 09:00 | Course: BIC1214 (LAB) | Room: PHAR_PGLAB | Lecturer: TS. DR. SUKHMINDER KAUR
# 08:00 ~ 09:00 | Course: BP172 (LECTURE) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 08:00 ~ 09:00 | Course: BP265 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 08:00 ~ 11:00 | Course: BSE1013 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASSOC. PROF. DR. AZHAR MD ADNAN
# 08:00 ~ 10:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 08:00 ~ 10:00 | Course: DEX1034 (ART) | Room: C404 | Lecturer: TS. MUHAMAD FALIQ MOHAMAD NAZER
# 08:00 ~ 09:00 | Course: FAS1064 (LECTURE) | Room: MPH - GBS | Lecturer: AIN ATIQA MUSTAPHA
# 08:00 ~ 11:00 | Course: FHA1283 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. LOKE HOI WENG
# 08:00 ~ 11:00 | Course: OP215 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. VIJAYA LECHIMI RAJ A/P T M RAJAGOPAL
# 08:00 ~ 10:00 | Course: OP222 (LECTURE) | Room: C3M05 | Lecturer: PREMA A/P MUTHIAH
# 08:00 ~ 11:00 | Course: OP416 (LECTURE) | Room: C404 | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 08:00 ~ 09:00 | Course: PST1024B (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH
# 09:00 ~ 10:00 | Course: BAN1054 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 09:00 ~ 10:00 | Course: BAN1054 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 09:00 ~ 10:00 | Course: BBA1703 (TUTORIAL) | Room: MPH - GBS | Lecturer: BRAHAM RAHUL RAM A/L JAMNADAS
# 09:00 ~ 10:00 | Course: BBB1033 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. SOO XIN LIN
# 09:00 ~ 12:00 | Course: BEQ3013 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: TS. DR. KHAIRUL ZAHREEN MOHD AROF
# 09:00 ~ 10:00 | Course: BP291 (TUTORIAL) | Room: MPH - GBS | Lecturer: AUDREY KOW SIEW FOONG
# 09:00 ~ 10:00 | Course: BP472 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 09:00 ~ 10:00 | Course: BPC2104 (TUTORIAL) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 09:00 ~ 10:00 | Course: BPC3152 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. MALARVILI A/P SELVARAJA
# 09:00 ~ 12:00 | Course: FAF1023 (LECTURE) | Room: MPH - GBS | Lecturer: DR. CHANG LEE SIN
# 09:00 ~ 11:00 | Course: OP416 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 10:00 ~ 13:00 | Course: BAB1053 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 10:00 ~ 12:00 | Course: BBA1093 (LECTURE) | Room: None | Lecturer: ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD
# 10:00 ~ 11:00 | Course: BEX1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: SHAHID MANZOOR
# 10:00 ~ 13:00 | Course: BIC1214 (LECTURE) | Room: MPH - GBS | Lecturer: TS. DR. SUKHMINDER KAUR
# 10:00 ~ 11:00 | Course: BP497 (TUTORIAL) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 10:00 ~ 13:00 | Course: BSE1063 (LECTURE) | Room: C3M05 | Lecturer: DR. ALADDIN Y.M. ASSAIQELI
# 10:00 ~ 11:00 | Course: CD204 (TUTORIAL) | Room: C3M05 | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 10:00 ~ 12:00 | Course: CD204 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 10:00 ~ 11:00 | Course: DBL1034 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. MOKANA A/P MUTHU KUMARASAMY
# 10:00 ~ 11:00 | Course: FBF1064 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 10:00 ~ 12:00 | Course: FBF1093 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 10:00 ~ 11:00 | Course: FSL1204 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ALI KHODI
# 10:00 ~ 13:00 | Course: OP224 (LECTURE) | Room: MPH - GBS | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 10:00 ~ 13:00 | Course: OP413 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASSISTANT PROFESSOR DR. TEOH SWEE CHAI
# 10:00 ~ 12:00 | Course: SM106 (LECTURE) | Room: MPH - GBS | Lecturer: MD SHAM SAMAD
# 11:00 ~ 12:00 | Course: BBA2223 (TUTORIAL) | Room: MPH - GBS | Lecturer: SHAKERIN ISMAIL
# 11:00 ~ 12:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 11:00 ~ 13:00 | Course: BBB1033 (LECTURE) | Room: None | Lecturer: DR. SOO XIN LIN
# 11:00 ~ 14:00 | Course: BEA2068 (LECTURE) | Room: MPH - GBS | Lecturer: IDA MARLINA MAZLAN
# 11:00 ~ 14:00 | Course: BEQ2014 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: TS. SR KHOO SUI LAI
# 11:00 ~ 12:00 | Course: BIC1144 (LAB) | Room: C LAB C | Lecturer: ASST. PROF. DR. CHLOE THONG CHEE LING
# 11:00 ~ 12:00 | Course: BP254 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 11:00 ~ 12:00 | Course: BP291 (LECTURE) | Room: MPH - GBS | Lecturer: AUDREY KOW SIEW FOONG
# 11:00 ~ 12:00 | Course: BP381 (TUTORIAL) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 11:00 ~ 12:00 | Course: BP497 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 11:00 ~ 12:00 | Course: BPC2094 (LECTURE) | Room: C3M04B | Lecturer: DR. KUSHAGRA KHANNA
# 11:00 ~ 12:00 | Course: BPC3142 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 11:00 ~ 13:00 | Course: CET08 (LECTURE) | Room: C3M04B | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 11:00 ~ 13:00 | Course: CET09 (LECTURE) | Room: MPH - GBS | Lecturer: JONATHAN A/L ABISHEGAM
# 11:00 ~ 12:00 | Course: DA105 (LECTURE) | Room: MPH - GBS | Lecturer: KEVIN NG CHIN CHWEE
# 11:00 ~ 12:00 | Course: DBB1083 (TUTORIAL) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 11:00 ~ 14:00 | Course: FAS1024 (LAB) | Room: C311 PHYSICS LAB | Lecturer: DR. CHANG LEE SIN
# 11:00 ~ 14:00 | Course: FAS1044 (LAB) | Room: MICROB | Lecturer: KAVITA A/P CHIRARA
# 11:00 ~ 13:00 | Course: OP312 (LECTURE) | Room: C3M04B | Lecturer: NOORSHAZANA MAT REJAB @ MD REJAB
# 11:00 ~ 13:00 | Course: OP322 (LECTURE) | Room: C404 | Lecturer: NOORSHAZANA MAT REJAB @ MD REJAB
# 11:00 ~ 13:00 | Course: OP416 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 12:00 ~ 14:00 | Course: BBS1063 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 12:00 ~ 13:00 | Course: BP381 (LECTURE) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 12:00 ~ 13:00 | Course: BP495 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 12:00 ~ 13:00 | Course: DBB1014 (LECTURE) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 12:00 ~ 14:00 | Course: FAS1024 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. ALICE PHUA CHOON YEN
# 12:00 ~ 14:00 | Course: FBF1153 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. FATIMA NADEEM SALEM AL-ASWADI
# 12:00 ~ 15:00 | Course: FD202 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: NUR AMIRA ASYIKIN ZAHARI
# 12:00 ~ 15:00 | Course: MEA1024 (LECTURE) | Room: C3M04B | Lecturer: ASSISTANT PROFESSOR DR. ZHAO SHENGHUAN
# 12:00 ~ 14:00 | Course: OP315 (LECTURE) | Room: C3M05 | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 12:00 ~ 13:00 | Course: PST1024B (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. SIMRANJEET KAUR JUDGE A/P CHARANJEET SINGH
# 13:00 ~ 15:00 | Course: BAA2023 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW LI LEE
# 13:00 ~ 15:00 | Course: BAN1023 (LECTURE) | Room: C314 | Lecturer: DR. SHASHIKALA SIVAPATHY
# 13:00 ~ 14:00 | Course: BBA2033 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN
# 13:00 ~ 14:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: THILAGAVATHI A/P MUTTU
# 13:00 ~ 14:00 | Course: BBB1033 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. SOO XIN LIN
# 13:00 ~ 16:00 | Course: BFD107 (LECTURE) | Room: C3M05 | Lecturer: NUR AMIRA ASYIKIN ZAHARI
# 13:00 ~ 14:00 | Course: BIB3103T (LAB) | Room: C311 PHYSICS LAB | Lecturer: TBA5
# 13:00 ~ 14:00 | Course: BPC2084 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 13:00 ~ 14:00 | Course: BPC2094 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. KUSHAGRA KHANNA
# 13:00 ~ 14:00 | Course: DBL1034 (TUTORIAL) | Room: C3M05 | Lecturer: DR. MOKANA A/P MUTHU KUMARASAMY
# 13:00 ~ 16:00 | Course: FAS1034 (LAB) | Room: None | Lecturer: DR. MICHELLE TEO YEE MUN
# 13:00 ~ 16:00 | Course: FD202 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: NUR AMIRA ASYIKIN ZAHARI
# 13:00 ~ 14:00 | Course: FSP1444 (TUTORIAL) | Room: MPH - GBS | Lecturer: CHEAH HAN LIN
# 14:00 ~ 17:00 | Course: AI663 (LECTURE) | Room: C3M05 | Lecturer: NUR RAFIDA HAMZAH
# 14:00 ~ 16:00 | Course: BAN1042 (LECTURE) | Room: MPH - GBS | Lecturer: DR. NURLIYANA ABDUL RAZAK
# 14:00 ~ 15:00 | Course: BBA1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
# 14:00 ~ 15:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 14:00 ~ 15:00 | Course: BBB1033 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. SOO XIN LIN
# 14:00 ~ 15:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 14:00 ~ 15:00 | Course: BEA1083 (LECTURE) | Room: C3M05 | Lecturer: TS. MALIZA ISMAIL JAMAIL
# 14:00 ~ 17:00 | Course: BEQ4043 (LECTURE) | Room: C404 | Lecturer: DR. ZAIRRA MAT JUSOH
# 14:00 ~ 15:00 | Course: BPC2084 (TUTORIAL) | Room: C3M05 | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 14:00 ~ 16:00 | Course: CET07 (LECTURE) | Room: C314 | Lecturer: DR. FATEMEH AMIRI
# 14:00 ~ 17:00 | Course: DA101 (LECTURE) | Room: C404 | Lecturer: IVAN LAM WAI HOE
# 14:00 ~ 17:00 | Course: DAA1074 (LAB) | Room: C311 PHYSICS LAB | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 14:00 ~ 16:00 | Course: DEX1034 (ART) | Room: GROUP THERAPY ROOM | Lecturer: TS. MUHAMAD FALIQ MOHAMAD NAZER
# 14:00 ~ 16:00 | Course: FAS1044 (LECTURE) | Room: C314 | Lecturer: KAVITA A/P CHIRARA
# 14:00 ~ 15:00 | Course: FBF1054 (LECTURE) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 14:00 ~ 15:00 | Course: FBF1064 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 14:00 ~ 16:00 | Course: FBF1404 (LECTURE) | Room: MPH - GBS | Lecturer: AZMIR ISMAIL
# 14:00 ~ 15:00 | Course: MPU2221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 15:00 ~ 18:00 | Course: AD332 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: NOR SYAWALLINA AZMAN
# 15:00 ~ 16:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 15:00 ~ 18:00 | Course: BEA1033 (LECTURE) | Room: MPH - GBS | Lecturer: INTAN LIANA SAMSUDIN
# 15:00 ~ 18:00 | Course: BEA1083 (LECTURE) | Room: C314 | Lecturer: TS. MALIZA ISMAIL JAMAIL
# 15:00 ~ 18:00 | Course: BEQ1074 (LECTURE) | Room: C3M05 | Lecturer: TS. IRNA NURSYAFINA ROSDI
# 15:00 ~ 16:00 | Course: BEX1033 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. LAI LI SZE
# 15:00 ~ 17:00 | Course: BIB3103 (LECTURE) | Room: MPH - GBS | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 15:00 ~ 16:00 | Course: BIB3103T (LAB) | Room: C LAB C | Lecturer: TBA5
# 15:00 ~ 16:00 | Course: DBB1014 (LECTURE) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 15:00 ~ 17:00 | Course: FBF1374 (LECTURE) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 15:00 ~ 16:00 | Course: FBF1394 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 15:00 ~ 18:00 | Course: OP422 (PBL) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NOORSHAZANA MAT REJAB @ MD REJAB
# 15:00 ~ 18:00 | Course: SP208 (LECTURE) | Room: MPH - GBS | Lecturer: ARMAN IMRAN ASHOK
# 16:00 ~ 18:00 | Course: BAC1064 (LECTURE) | Room: C404 | Lecturer: DR. REVATHI A/P RAJAN
# 16:00 ~ 17:00 | Course: BBL1013 (TUTORIAL) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. NOORSIAH AHMAD
# 16:00 ~ 19:00 | Course: BEA1073 (LECTURE) | Room: C3M05 | Lecturer: BAKHTIAR AMIR
# 16:00 ~ 18:00 | Course: BEA3018 (LECTURE) | Room: C404 | Lecturer: YUSRA ZULKIFLI
# 16:00 ~ 19:00 | Course: BEQ1014 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. ZAIRRA MAT JUSOH
# 16:00 ~ 17:00 | Course: BEX1013 (LECTURE) | Room: None | Lecturer: TEY WAH YEN
# 16:00 ~ 17:00 | Course: BEX1023 (LECTURE) | Room: None | Lecturer: NORRABIATUL ADAWIYAH JUSOH
# 16:00 ~ 18:00 | Course: BEX1023 (LECTURE) | Room: None | Lecturer: NORRABIATUL ADAWIYAH JUSOH
# 16:00 ~ 17:00 | Course: BP452 (LECTURE) | Room: MPH - GBS | Lecturer: ASSOC. PROF. DR. PALANIRAJAN VIJAYARAJ KUMAR
# 16:00 ~ 18:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 16:00 ~ 18:00 | Course: CET07 (LECTURE) | Room: C314 | Lecturer: DR. FATEMEH AMIRI
# 16:00 ~ 17:00 | Course: DBB1014 (TUTORIAL) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 16:00 ~ 18:00 | Course: FAS1034 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MICHELLE TEO YEE MUN
# 16:00 ~ 19:00 | Course: FAS1064 (LAB) | Room: PSYCHO_LAB | Lecturer: AIN ATIQA MUSTAPHA
# 16:00 ~ 17:00 | Course: FBF1054 (TUTORIAL) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 16:00 ~ 17:00 | Course: FBF1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 17:00 ~ 20:00 | Course: AD133 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AMAR MUHAMMAD RAMLI
# 17:00 ~ 18:00 | Course: BBA1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
# 17:00 ~ 20:00 | Course: BEI2017 (LECTURE) | Room: MPH - GBS | Lecturer: DR. WONG LEONG YEE
# 17:00 ~ 20:00 | Course: BEQ2073 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. WONG LEONG YEE
# 17:00 ~ 18:00 | Course: BIC1233 (LAB) | Room: C LAB C | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 17:00 ~ 18:00 | Course: BPC1063 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. RAVISHANKAR RAM MANI
# 17:00 ~ 19:00 | Course: CD102 (LAB) | Room: ADVANCE INDUSTRIAL ROBOTIC LAB - BLOCK C | Lecturer: SALEH ABDULALEM ALI MOHAMMED
# 17:00 ~ 19:00 | Course: CET08 (LECTURE) | Room: C3M05 | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 17:00 ~ 19:00 | Course: CET09 (LECTURE) | Room: C3M05 | Lecturer: JONATHAN A/L ABISHEGAM
# 17:00 ~ 18:00 | Course: FAS1044 (LECTURE) | Room: C3M04B | Lecturer: KAVITA A/P CHIRARA
# 17:00 ~ 19:00 | Course: FAS1064 (LECTURE) | Room: MPH - GBS | Lecturer: AIN ATIQA MUSTAPHA
# 17:00 ~ 18:00 | Course: FBF1404 (TUTORIAL) | Room: MPH - GBS | Lecturer: AZMIR ISMAIL
# 18:00 ~ 19:00 | Course: BEI1055 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 18:00 ~ 21:00 | Course: BEI2043 (LECTURE) | Room: C3M04B | Lecturer: SHAWN LEISHMAN
# 18:00 ~ 21:00 | Course: BEQ1043 (LECTURE) | Room: MPH - GBS | Lecturer: TS. DR. KHAIRUL ZAHREEN MOHD AROF
# 18:00 ~ 21:00 | Course: BEQ30610 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: TS. SR KHOO SUI LAI
# 18:00 ~ 21:00 | Course: BEQ4014 (LECTURE) | Room: C314 | Lecturer: NURINA NAWI
# 18:00 ~ 21:00 | Course: BFD203 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ZAREENA TAJUL MUHAMMAD MAJIDI
# 18:00 ~ 19:00 | Course: BP477 (LECTURE) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 18:00 ~ 19:00 | Course: BPC1093 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. LOW MAY LEE
# 18:00 ~ 20:00 | Course: CET04 (LECTURE) | Room: None | Lecturer: ARVIND A/L DAVID
# 18:00 ~ 20:00 | Course: CET09 (LECTURE) | Room: C3M05 | Lecturer: JONATHAN A/L ABISHEGAM
# 18:00 ~ 21:00 | Course: DFS121 (LECTURE) | Room: C404 | Lecturer: ELNAZ ROSTAMIGHARAGOZLOO
# 18:00 ~ 20:00 | Course: FAS1074 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. AMMAR ABDULAZIZ MAJEED AL-TALIB
# 18:00 ~ 20:00 | Course: MPU3232 (LECTURE) | Room: None | Lecturer: NORFAIZADATUL AKMA MOHAMAD MASWAN
# 18:00 ~ 20:00 | Course: OP225 (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 18:00 ~ 21:00 | Course: SM115 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. VIMALA A/P GOVINDASAMY
# 19:00 ~ 20:00 | Course: BP172 (LECTURE) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 19:00 ~ 20:00 | Course: BP181 (LECTURE) | Room: MPH - GBS | Lecturer: AUDREY KOW SIEW FOONG
# 19:00 ~ 20:00 | Course: BPC3093 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AUDREY KOW SIEW FOONG
# 19:00 ~ 21:00 | Course: CET09 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: JONATHAN A/L ABISHEGAM
# 19:00 ~ 21:00 | Course: FAS1053 (LAB) | Room: BIOTECH FERM | Lecturer: FARHANA ABDUL BARRI
# 19:00 ~ 20:00 | Course: FBF1124 (TUTORIAL) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 19:00 ~ 20:00 | Course: OP321 (LECTURE) | Room: C314 | Lecturer: IRFAH AMIRIN
# 20:00 ~ 21:00 | Course: BBA1703 (TUTORIAL) | Room: MPH - GBS | Lecturer: BRAHAM RAHUL RAM A/L JAMNADAS
# 20:00 ~ 21:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 20:00 ~ 21:00 | Course: BP265 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 20:00 ~ 21:00 | Course: BP267 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 20:00 ~ 21:00 | Course: BP364 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 20:00 ~ 21:00 | Course: OP213 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
#
# ----- Wed -----
# 08:00 ~ 11:00 | Course: BAN1042 (LECTURE) | Room: MPH - GBS | Lecturer: DR. NURLIYANA ABDUL RAZAK
# 08:00 ~ 09:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 08:00 ~ 10:00 | Course: BBB1023 (LECTURE) | Room: None | Lecturer: DR. WONG HOONG SANG
# 08:00 ~ 09:00 | Course: BEX1013 (LECTURE) | Room: None | Lecturer: TEY WAH YEN
# 08:00 ~ 10:00 | Course: BIC1123 (LECTURE) | Room: None | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 08:00 ~ 09:00 | Course: BP181 (LECTURE) | Room: MPH - GBS | Lecturer: AUDREY KOW SIEW FOONG
# 08:00 ~ 09:00 | Course: BP265 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 08:00 ~ 09:00 | Course: BP372 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 08:00 ~ 09:00 | Course: BPC2122 (GENERAL) | Room: C404 | Lecturer: ASSOCIATE PROFESSOR DR. MAI CHUN WAI
# 08:00 ~ 10:00 | Course: CET08 (LECTURE) | Room: C314 | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 08:00 ~ 11:00 | Course: DAA1074 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 08:00 ~ 10:00 | Course: DBL1034 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. MOKANA A/P MUTHU KUMARASAMY
# 08:00 ~ 09:00 | Course: FBF1114 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 08:00 ~ 11:00 | Course: FSM1253 (LECTURE) | Room: None | Lecturer: DR. SRI AZRA ATTAN
# 08:00 ~ 11:00 | Course: SM115 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. VIMALA A/P GOVINDASAMY
# 09:00 ~ 10:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 09:00 ~ 11:00 | Course: BBL1013 (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. NOORSIAH AHMAD
# 09:00 ~ 12:00 | Course: BEQ1014 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. ZAIRRA MAT JUSOH
# 09:00 ~ 10:00 | Course: BEX1033 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. LAI LI SZE
# 09:00 ~ 10:00 | Course: BIC1144T (LAB) | Room: PHAR_PGLAB | Lecturer: TBA5
# 09:00 ~ 10:00 | Course: BIC1233 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 09:00 ~ 12:00 | Course: DFS122 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: MUHAMMAD ARIFF NORDIN
# 09:00 ~ 12:00 | Course: FAS1044 (LAB) | Room: MICROB | Lecturer: KAVITA A/P CHIRARA
# 09:00 ~ 10:00 | Course: FBF1124 (TUTORIAL) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 09:00 ~ 11:00 | Course: FBF1173 (LECTURE) | Room: MPH - GBS | Lecturer: DR. USMAN AKBAR
# 09:00 ~ 12:00 | Course: OP123 (LECTURE) | Room: C314 | Lecturer: ASSOC. PROF. DR. LILI ASMA
# 09:00 ~ 10:00 | Course: OP214 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 09:00 ~ 12:00 | Course: SP110 (LECTURE) | Room: C314 | Lecturer: ASSISTANT PROFESSOR DR. SAEID MOTEVALLI
# 10:00 ~ 13:00 | Course: AD133 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AMAR MUHAMMAD RAMLI
# 10:00 ~ 13:00 | Course: BAB1053 (LECTURE) | Room: C3M05 | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 10:00 ~ 13:00 | Course: BAN1054 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 10:00 ~ 12:00 | Course: BEA1015 (LECTURE) | Room: None | Lecturer: NICHOLAS NG KHOON WU
# 10:00 ~ 13:00 | Course: BEA30410 (LECTURE) | Room: MPH - GBS | Lecturer: CHEAH EE VON
# 10:00 ~ 12:00 | Course: BEX1033 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. LAI LI SZE
# 10:00 ~ 11:00 | Course: BP495 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 10:00 ~ 11:00 | Course: BPC1073 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. RAVISHANKAR RAM MANI
# 10:00 ~ 11:00 | Course: BPC3113 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 10:00 ~ 13:00 | Course: BSE1063 (LECTURE) | Room: C314 | Lecturer: DR. ALADDIN Y.M. ASSAIQELI
# 10:00 ~ 11:00 | Course: DBB1083 (TUTORIAL) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 10:00 ~ 13:00 | Course: FAS1034 (LAB) | Room: None | Lecturer: DR. MICHELLE TEO YEE MUN
# 10:00 ~ 11:00 | Course: MEA1018 (LECTURE) | Room: MPH - GBS | Lecturer: YUSRA ZULKIFLI
# 10:00 ~ 13:00 | Course: MEA1093 (LECTURE) | Room: MPH - GBS | Lecturer: DR. WONG LEONG YEE
# 10:00 ~ 13:00 | Course: PST1014B (LECTURE) | Room: C314 | Lecturer: ASST. PROF. DR. ZAIDA MUSTAFA
# 10:00 ~ 12:00 | Course: SE005 (TUTORIAL) | Room: MPH - GBS | Lecturer: DAPHNE WOON DEIN LUEN
# 10:00 ~ 12:00 | Course: SP121 (TUTORIAL) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. TAN LI HUAN
# 11:00 ~ 14:00 | Course: AB618 (LECTURE) | Room: C3M04B | Lecturer: NURUL ANIDA MOHAMAD
# 11:00 ~ 12:00 | Course: BAB1044 (LECTURE) | Room: MPH - GBS | Lecturer: DR. LAU YIN YIN
# 11:00 ~ 12:00 | Course: BAB1053 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 11:00 ~ 12:00 | Course: BAB1053 (LECTURE) | Room: C404 | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 11:00 ~ 12:00 | Course: BAC1064 (LECTURE) | Room: C3M05 | Lecturer: DR. REVATHI A/P RAJAN
# 11:00 ~ 14:00 | Course: BAF1024 (LAB) | Room: None | Lecturer: PROF. DR. NYAM KAR LIN
# 11:00 ~ 14:00 | Course: BAN2024 (LAB) | Room: BIOCHEM | Lecturer: PROF. DR. NYAM KAR LIN
# 11:00 ~ 13:00 | Course: BBA1093 (LECTURE) | Room: None | Lecturer: ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD
# 11:00 ~ 12:00 | Course: BBA1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD
# 11:00 ~ 12:00 | Course: BEI1055 (LECTURE) | Room: MPH - GBS | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 11:00 ~ 14:00 | Course: BEI1083 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NURUL ANIDA MOHAMAD
# 11:00 ~ 13:00 | Course: BEI2017 (LECTURE) | Room: MPH - GBS | Lecturer: DR. WONG LEONG YEE
# 11:00 ~ 12:00 | Course: BEI2067 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 11:00 ~ 14:00 | Course: BEQ2033 (LECTURE) | Room: C404 | Lecturer: TS. IRNA NURSYAFINA ROSDI
# 11:00 ~ 14:00 | Course: BEQ2064 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: SR. LUQMAN A ZAMANI
# 11:00 ~ 13:00 | Course: BEX1033 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. LAI LI SZE
# 11:00 ~ 12:00 | Course: BPC2132 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 11:00 ~ 13:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 11:00 ~ 13:00 | Course: FAS1053 (LECTURE) | Room: None | Lecturer: FARHANA ABDUL BARRI
# 11:00 ~ 12:00 | Course: FBF1074 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 11:00 ~ 13:00 | Course: FBF1364 (LECTURE) | Room: None | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
# 11:00 ~ 12:00 | Course: MEA1018 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: YUSRA ZULKIFLI
# 11:00 ~ 14:00 | Course: OP311 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 12:00 ~ 14:00 | Course: BAA2023 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW LI LEE
# 12:00 ~ 13:00 | Course: BBB1033 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. SOO XIN LIN
# 12:00 ~ 15:00 | Course: BEA1055 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: BAKHTIAR AMIR
# 12:00 ~ 15:00 | Course: BEA2053 (LECTURE) | Room: MPH - GBS | Lecturer: TS. CHAN CHIEW CHUEN
# 12:00 ~ 15:00 | Course: BEI1073 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 12:00 ~ 15:00 | Course: BEQ1103 (LECTURE) | Room: C3M05 | Lecturer: DR. NORSHAKILA MUHAMAD RAWAI
# 12:00 ~ 13:00 | Course: BPC3083 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. LOW MAY LEE
# 12:00 ~ 15:00 | Course: DAA1074 (LECTURE) | Room: C404 | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 12:00 ~ 13:00 | Course: DBA1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MAHALAKSHMI A/P SUPPIAH
# 12:00 ~ 15:00 | Course: DPB1014 (KITCHEN) | Room: C314 | Lecturer: SH MARIA SAHILA BT SYED ALI HASSAN
# 12:00 ~ 15:00 | Course: FAS1024 (LAB) | Room: MICROB | Lecturer: DR. CHANG LEE SIN
# 12:00 ~ 13:00 | Course: FBF1064 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 12:00 ~ 13:00 | Course: FBF1114 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 12:00 ~ 13:00 | Course: FBF1114 (LECTURE) | Room: None | Lecturer: DR. ENG POH HWA
# 12:00 ~ 15:00 | Course: MPP1074 (LECTURE) | Room: C404 | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 12:00 ~ 13:00 | Course: MPU3221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 13:00 ~ 15:00 | Course: BBL1013 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: ASST. PROF. DR. NOORSIAH AHMAD
# 13:00 ~ 15:00 | Course: BBS1034 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 13:00 ~ 15:00 | Course: BEA1055 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: BAKHTIAR AMIR
# 13:00 ~ 16:00 | Course: BEA3023 (LECTURE) | Room: MPH - GBS | Lecturer: PROFESSOR DR. NANGKULA UTABERTA
# 13:00 ~ 16:00 | Course: BEI2033 (LECTURE) | Room: C314 | Lecturer: HUMANSON GIMFIL
# 13:00 ~ 14:00 | Course: BP112 (LECTURE) | Room: None | Lecturer: PROFESSOR DR. SAAD TAYYAB
# 13:00 ~ 14:00 | Course: BPC3103 (TUTORIAL) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 13:00 ~ 14:00 | Course: CD102 (LECTURE) | Room: C3M05 | Lecturer: SALEH ABDULALEM ALI MOHAMMED
# 13:00 ~ 15:00 | Course: CET05 (LECTURE) | Room: None | Lecturer: MELISSA WONG LING LEE
# 13:00 ~ 15:00 | Course: FAS1034 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MICHELLE TEO YEE MUN
# 13:00 ~ 16:00 | Course: OP316 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: DAPHNE WOON DEIN LUEN
# 13:00 ~ 16:00 | Course: OP416 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 13:00 ~ 16:00 | Course: PST1014B (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. ZAIDA MUSTAFA
# 13:00 ~ 14:00 | Course: SM106 (LECTURE) | Room: None | Lecturer: MD SHAM SAMAD
# 13:00 ~ 16:00 | Course: SP206 (LECTURE) | Room: C3M05 | Lecturer: NURUL HIDAYAH BT MOHD SA'AT
# 14:00 ~ 15:00 | Course: AB618 (LECTURE) | Room: C3M05 | Lecturer: NURUL ANIDA MOHAMAD
# 14:00 ~ 16:00 | Course: BAN1023 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: DR. SHASHIKALA SIVAPATHY
# ...
# 08:00 ~ 09:00 | Course: DBB1083 (TUTORIAL) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 08:00 ~ 11:00 | Course: DFS114 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASSISTANT PROFESSOR TS. LUCAS LIM BOON LEONG
# 08:00 ~ 10:00 | Course: FAS1053 (LAB) | Room: CE LAB | Lecturer: FARHANA ABDUL BARRI
# 08:00 ~ 09:00 | Course: FPC1023 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEONG KOK WHYE
# 08:00 ~ 10:00 | Course: OP325 (LECTURE) | Room: C314 | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 08:00 ~ 10:00 | Course: OP415 (LECTURE) | Room: C3M04B | Lecturer: ASSOC. PROF. DR. LILI ASMA
# 08:00 ~ 11:00 | Course: SP121 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. TAN LI HUAN
# 09:00 ~ 10:00 | Course: BAN1023 (LECTURE) | Room: MPH - GBS | Lecturer: DR. SHASHIKALA SIVAPATHY
# 09:00 ~ 11:00 | Course: BAN1042 (LECTURE) | Room: C3M04B | Lecturer: DR. NURLIYANA ABDUL RAZAK
# 09:00 ~ 10:00 | Course: BBA1093 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. MOHAMAD AZNILLAH AHMAD
# 09:00 ~ 10:00 | Course: BEA1043 (LECTURE) | Room: MPH - GBS | Lecturer: NICHOLAS NG KHOON WU
# 09:00 ~ 12:00 | Course: BEA1063 (LECTURE) | Room: MPH - GBS | Lecturer: DR. KHOO FONG YI
# 09:00 ~ 12:00 | Course: BEQ2093 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: TS. SR KHOO SUI LAI
# 09:00 ~ 11:00 | Course: BEX1013 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. TENG KAH HOU
# 09:00 ~ 12:00 | Course: BHA1023 (LECTURE) | Room: MPH - GBS | Lecturer: SULIZA HAIRON
# 09:00 ~ 11:00 | Course: BIC1144 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. ISMAIL AHMED AL-QASEM AL-HADI
# 09:00 ~ 10:00 | Course: BP132 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 09:00 ~ 10:00 | Course: BPC3103 (LECTURE) | Room: C3M04B | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 09:00 ~ 11:00 | Course: CET07 (LECTURE) | Room: C3M05 | Lecturer: DR. FATEMEH AMIRI
# 09:00 ~ 11:00 | Course: CET08 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 09:00 ~ 10:00 | Course: FAS1014 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. ALICE PHUA CHOON YEN
# 09:00 ~ 12:00 | Course: FEA1343 (LECTURE) | Room: MPH - GBS | Lecturer: TAN HAN LEONG
# 10:00 ~ 11:00 | Course: BBS1034 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 10:00 ~ 13:00 | Course: BEA2083 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. ZHAO SHENGHUAN
# 10:00 ~ 13:00 | Course: BEI2053 (LECTURE) | Room: C314 | Lecturer: FOO HSIANG HSIEN
# 10:00 ~ 11:00 | Course: BEX1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. TS. DR. YU LIH JIUN
# 10:00 ~ 12:00 | Course: BIC1144 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. ISMAIL AHMED AL-QASEM AL-HADI
# 10:00 ~ 12:00 | Course: BIC1233 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. UMM E MARIYA SHAH
# 10:00 ~ 11:00 | Course: BP112 (LECTURE) | Room: None | Lecturer: PROFESSOR DR. SAAD TAYYAB
# 10:00 ~ 13:00 | Course: DA102 (LECTURE) | Room: MPH - GBS | Lecturer: IVAN LAM WAI HOE
# 10:00 ~ 12:00 | Course: OP225 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. VIJAYA LECHIMI RAJ A/P T M RAJAGOPAL
# 10:00 ~ 12:00 | Course: OP325 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: AL KHUSAIRI AIDID ABU ASMARA
# 11:00 ~ 14:00 | Course: AB443 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NURUL ANIDA MOHAMAD
# 11:00 ~ 12:00 | Course: BBB1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. WONG HOONG SANG
# 11:00 ~ 12:00 | Course: BEE1023 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN
# 11:00 ~ 14:00 | Course: BEQ4014 (LECTURE) | Room: C314 | Lecturer: NURINA NAWI
# 11:00 ~ 13:00 | Course: CET01 (LECTURE) | Room: C3M05 | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 11:00 ~ 13:00 | Course: CET01 (LECTURE) | Room: MPH - GBS | Lecturer: CFL TBA1
# 11:00 ~ 12:00 | Course: FBF1364 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
# 11:00 ~ 14:00 | Course: FSP1213 (LECTURE) | Room: MPH - GBS | Lecturer: NURUL HIDAYAH BT MOHD SA'AT
# 11:00 ~ 14:00 | Course: MEA1018 (LECTURE) | Room: GROUP THERAPY ROOM | Lecturer: YUSRA ZULKIFLI
# 11:00 ~ 13:00 | Course: OP114 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: DR. SANGAR A/L SUBRAMANIAM
# 11:00 ~ 14:00 | Course: OP121 (LECTURE) | Room: C404 | Lecturer: ESTHER LAU SIEW SIENG
# 11:00 ~ 12:00 | Course: OP221 (LECTURE) | Room: C3M05 | Lecturer: SATHIYA PRAKASH A/L SOORYANARAYANA
# 11:00 ~ 13:00 | Course: SE005 (TUTORIAL) | Room: MPH - GBS | Lecturer: DAPHNE WOON DEIN LUEN
# 11:00 ~ 12:00 | Course: SE123 (TUTORIAL) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASSISTANT PROFESSOR DR. GENEVIEVE FLORES DIPOLOG
# 11:00 ~ 13:00 | Course: SM106 (LECTURE) | Room: None | Lecturer: MD SHAM SAMAD
# 12:00 ~ 13:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 12:00 ~ 14:00 | Course: BIB3103 (LECTURE) | Room: MPH - GBS | Lecturer: GLARET SHIRLEY A/P SINNAPPAN
# 12:00 ~ 13:00 | Course: BP172 (TUTORIAL) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 12:00 ~ 14:00 | Course: CET04 (LECTURE) | Room: None | Lecturer: ARVIND A/L DAVID
# 12:00 ~ 14:00 | Course: CET04 (LECTURE) | Room: None | Lecturer: ARVIND A/L DAVID
# 12:00 ~ 13:00 | Course: DBL1034 (TUTORIAL) | Room: C404 | Lecturer: DR. MOKANA A/P MUTHU KUMARASAMY
# 12:00 ~ 15:00 | Course: FAS1034 (LAB) | Room: None | Lecturer: DR. MICHELLE TEO YEE MUN
# 13:00 ~ 16:00 | Course: BAN1054 (LAB) | Room: None | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 13:00 ~ 16:00 | Course: BEA3034 (LECTURE) | Room: MPH - GBS | Lecturer: NURHAYATI ZULKEPLY
# 13:00 ~ 16:00 | Course: BEI1055 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 13:00 ~ 16:00 | Course: BEI2023 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 13:00 ~ 16:00 | Course: BEQ2064 (LECTURE) | Room: C314 | Lecturer: SR. LUQMAN A ZAMANI
# 13:00 ~ 14:00 | Course: BIC1144T (LAB) | Room: PHAR_PGLAB | Lecturer: TBA5
# 13:00 ~ 14:00 | Course: BP265 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. TS. DR. LEE MING TATT
# 13:00 ~ 14:00 | Course: BP372 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. FAZLOLLAH KESHAVARZI
# 13:00 ~ 14:00 | Course: BPC2094 (LECTURE) | Room: C3M05 | Lecturer: DR. KUSHAGRA KHANNA
# 13:00 ~ 15:00 | Course: CET04 (LECTURE) | Room: None | Lecturer: ARVIND A/L DAVID
# 13:00 ~ 15:00 | Course: CET08 (LECTURE) | Room: C3M05 | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 13:00 ~ 16:00 | Course: DFS113 (LECTURE) | Room: C314 | Lecturer: NABIELA AMINUDIN
# 13:00 ~ 15:00 | Course: FBF1074 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 13:00 ~ 14:00 | Course: FBF1394 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 13:00 ~ 14:00 | Course: FBF1394 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 13:00 ~ 15:00 | Course: MPU2332 (LECTURE) | Room: None | Lecturer: DR SHANTHIAH A/P RAJAGOPAL
# 13:00 ~ 14:00 | Course: PST1014B (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. ZAIDA MUSTAFA
# 13:00 ~ 14:00 | Course: SE121 (LECTURE) | Room: C3M05 | Lecturer: DR. ALADDIN Y.M. ASSAIQELI
# 13:00 ~ 16:00 | Course: SM101 (LECTURE) | Room: None | Lecturer: ASST. PROF. DR. ALWYN LAU WING WANG
# 14:00 ~ 17:00 | Course: BAB1044 (LAB) | Room: None | Lecturer: DR. LAU YIN YIN
# 14:00 ~ 17:00 | Course: BAC1064 (LECTURE) | Room: C404 | Lecturer: DR. REVATHI A/P RAJAN
# 14:00 ~ 15:00 | Course: BBS1014 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 14:00 ~ 15:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 14:00 ~ 15:00 | Course: BBS1063 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. KALPANA MUTHUSAMY
# 14:00 ~ 17:00 | Course: BEI2074 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. IDR BAIZURA HANIM BT BIDIN
# 14:00 ~ 17:00 | Course: BEQ3033 (LECTURE) | Room: C3M04B | Lecturer: DR. NORSHAKILA MUHAMAD RAWAI
# 14:00 ~ 17:00 | Course: BEQ4023 (LECTURE) | Room: C3M05 | Lecturer: TS. IRNA NURSYAFINA ROSDI
# 14:00 ~ 17:00 | Course: BFD107 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NUR AMIRA ASYIKIN ZAHARI
# 14:00 ~ 17:00 | Course: BHH1113 (LECTURE) | Room: MPH - GBS | Lecturer: DR. MARWA REFAAT MAHMOUD AHMED
# 14:00 ~ 15:00 | Course: BP353 (TUTORIAL) | Room: None | Lecturer: ASSOC. PROF. DR. PALANIRAJAN VIJAYARAJ KUMAR
# 14:00 ~ 15:00 | Course: BP364 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 14:00 ~ 15:00 | Course: BP497 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 14:00 ~ 15:00 | Course: BPC1073 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. RAVISHANKAR RAM MANI
# 14:00 ~ 16:00 | Course: CD211 (TUTORIAL) | Room: C404 | Lecturer: ASST. PROF. TS. DR. SHAYLA ISLAM
# 14:00 ~ 16:00 | Course: DBB1014 (LECTURE) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 14:00 ~ 17:00 | Course: DFS111 (LECTURE) | Room: C3M05 | Lecturer: ELNAZ ROSTAMIGHARAGOZLOO
# 14:00 ~ 15:00 | Course: FD202 (LECTURE) | Room: C3M04B | Lecturer: NUR AMIRA ASYIKIN ZAHARI
# 14:00 ~ 17:00 | Course: FSL1204 (LECTURE) | Room: C3M04B | Lecturer: ALI KHODI
# 14:00 ~ 17:00 | Course: SP110 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASSISTANT PROFESSOR DR. SAEID MOTEVALLI
# 15:00 ~ 16:00 | Course: BAB1053 (LECTURE) | Room: C3M05 | Lecturer: ASSOC. PROF. DR. ERIC CHAN WEI CHIANG
# 15:00 ~ 18:00 | Course: BAN1054 (LAB) | Room: None | Lecturer: ASST. PROF. DR. BASKARAN GUNASEKARAN
# 15:00 ~ 17:00 | Course: BBB1033 (LECTURE) | Room: None | Lecturer: DR. SOO XIN LIN
# 15:00 ~ 16:00 | Course: BFD203 (LECTURE) | Room: C3M05 | Lecturer: ZAREENA TAJUL MUHAMMAD MAJIDI
# 15:00 ~ 16:00 | Course: BP172 (GENERAL) | Room: MPH - GBS | Lecturer: VITHYAH A/P NADARAJA
# 15:00 ~ 16:00 | Course: BP497 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 15:00 ~ 16:00 | Course: BPC2132 (TUTORIAL) | Room: C3M05 | Lecturer: ASST. PROF. DR. CHEW YIK LING
# 15:00 ~ 17:00 | Course: CET01 (LECTURE) | Room: C314 | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 15:00 ~ 17:00 | Course: CET07 (LECTURE) | Room: MPH - GBS | Lecturer: DR. FATEMEH AMIRI
# 15:00 ~ 18:00 | Course: DA102 (LECTURE) | Room: C3M04B | Lecturer: IVAN LAM WAI HOE
# 15:00 ~ 16:00 | Course: DBL1034 (LECTURE) | Room: C314 | Lecturer: DR. MOKANA A/P MUTHU KUMARASAMY
# 15:00 ~ 17:00 | Course: FBF1054 (LECTURE) | Room: MPH - GBS | Lecturer: TAN FOOK ANN
# 15:00 ~ 16:00 | Course: FBF1114 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. ENG POH HWA
# 15:00 ~ 18:00 | Course: OP211 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASSISTANT PROFESSOR DR. TEOH SWEE CHAI
# 15:00 ~ 18:00 | Course: SP206 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: NURUL HIDAYAH BT MOHD SA'AT
# 15:00 ~ 17:00 | Course: SP208 (LECTURE) | Room: C314 | Lecturer: ARMAN IMRAN ASHOK
# 16:00 ~ 18:00 | Course: BBA2033 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN
# 16:00 ~ 17:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 16:00 ~ 17:00 | Course: BEX1023 (TUTORIAL) | Room: MPH - GBS | Lecturer: FETBE TBA10
# 16:00 ~ 18:00 | Course: BIB3103T (LECTURE) | Room: MPH - GBS | Lecturer: TBA5
# 16:00 ~ 17:00 | Course: BP263 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. SASIKALA CHINNAPPAN
# 16:00 ~ 17:00 | Course: BPC3093 (TUTORIAL) | Room: MPH - GBS | Lecturer: AUDREY KOW SIEW FOONG
# 16:00 ~ 17:00 | Course: BPC3113 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 16:00 ~ 18:00 | Course: CET08 (LECTURE) | Room: MPH - GBS | Lecturer: NUR AFIFAH DIYANAH SHAHARUDIN
# 16:00 ~ 17:00 | Course: FBF1124 (LECTURE) | Room: MPH - GBS | Lecturer: MARIAL ANNE A/P ANANDAN
# 16:00 ~ 17:00 | Course: MEA2018 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. AR. CHIA LIN LIN
# 16:00 ~ 18:00 | Course: OP424 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: ASST. PROF. DR. 'ADILAH MOHD ALI
# 17:00 ~ 20:00 | Course: BAC1064 (LAB) | Room: CHEM1 | Lecturer: DR. REVATHI A/P RAJAN
# 17:00 ~ 19:00 | Course: BAC1064 (LECTURE) | Room: C3M04B | Lecturer: DR. REVATHI A/P RAJAN
# 17:00 ~ 20:00 | Course: BAF1024 (LECTURE) | Room: MPH - GBS | Lecturer: PROF. DR. NYAM KAR LIN
# 17:00 ~ 19:00 | Course: BBA2223 (LECTURE) | Room: MPH - GBS | Lecturer: SHAKERIN ISMAIL
# 17:00 ~ 18:00 | Course: BBB1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. NORLIZA OMAR
# 17:00 ~ 18:00 | Course: BBB1033 (TUTORIAL) | Room: MPH - GBS | Lecturer: DR. SOO XIN LIN
# 17:00 ~ 19:00 | Course: BBM1073 (LECTURE) | Room: MPH - GBS | Lecturer: DR. NURKHALIDA MAKMOR
# 17:00 ~ 18:00 | Course: BBS1034 (TUTORIAL) | Room: C314 | Lecturer: ASST. PROF. DR. SATHIYARAJ THAMBIAYYA
# 17:00 ~ 18:00 | Course: BEX1013 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. JONATHAN YONG CHUNG EE
# 17:00 ~ 19:00 | Course: CET10 (LECTURE) | Room: C3M04B | Lecturer: SIVARANJINI A/P SUBRAMANIAM
# 17:00 ~ 20:00 | Course: FAS1034 (LAB) | Room: None | Lecturer: DR. MICHELLE TEO YEE MUN
# 17:00 ~ 18:00 | Course: MPU3221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 17:00 ~ 18:00 | Course: MPU3221 (LECTURE) | Room: None | Lecturer: DR. SITI NUR AAFIFAH HASHIM
# 18:00 ~ 19:00 | Course: BBA2033 (TUTORIAL) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. AHMAD NAZRI WAHIDUDIN
# 18:00 ~ 21:00 | Course: BEA1055 (LECTURE) | Room: C314 | Lecturer: BAKHTIAR AMIR
# 18:00 ~ 19:00 | Course: BEE1023 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. EUR ING. IR. VICTOR NAGESPARAN A/L AINARAPPAN
# 18:00 ~ 21:00 | Course: BEI1055 (LECTURE) | Room: C404 | Lecturer: RAJA HALIZA SUHAILA BTE RAJA ABD HAMID
# 18:00 ~ 19:00 | Course: BEX1023 (LECTURE) | Room: None | Lecturer: NORRABIATUL ADAWIYAH JUSOH
# 18:00 ~ 20:00 | Course: BIC1144 (LECTURE) | Room: MPH - GBS | Lecturer: ASSISTANT PROFESSOR DR. ISMAIL AHMED AL-QASEM AL-HADI
# 18:00 ~ 19:00 | Course: BP496 (LECTURE) | Room: MPH - GBS | Lecturer: RAMEZ AL KOUDMANI
# 18:00 ~ 19:00 | Course: BPC1093 (LECTURE) | Room: C3M05 | Lecturer: ASST. PROF. DR. LOW MAY LEE
# 18:00 ~ 19:00 | Course: BPC2084 (LECTURE) | Room: MPH - GBS | Lecturer: ASST. PROF. DR. ASHOK KUMAR JANAKIRAMAN
# 18:00 ~ 19:00 | Course: BPC3083 (TUTORIAL) | Room: C3M05 | Lecturer: ASST. PROF. DR. LOW MAY LEE
# 18:00 ~ 19:00 | Course: FPC1023 (LECTURE) | Room: C3M04B | Lecturer: ASST. PROF. DR. CHEONG KOK WHYE
# 18:00 ~ 20:00 | Course: MPU3232 (LECTURE) | Room: None | Lecturer: NORFAIZADATUL AKMA MOHAMAD MASWAN
# 19:00 ~ 20:00 | Course: BEI1063 (LECTURE) | Room: ANALYTICAL & SENSING, INSTRUMENTATIONS & CONTROL SYSTEM LABORATORY | Lecturer: LEONG YEAN TUCK
# 19:00 ~ 21:00 | Course: DBB1014 (LECTURE) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 19:00 ~ 20:00 | Course: OP321 (LECTURE) | Room: FOSSLA PHD MEETING ROOM | Lecturer: NORFATNIN AZMIN
# 20:00 ~ 21:00 | Course: BP266 (LECTURE) | Room: MPH - GBS | Lecturer: SABREEN YOUSIF MOHAMMED ALHASSAN NASR
# 20:00 ~ 21:00 | Course: BPC2104 (LECTURE) | Room: C314 | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 20:00 ~ 21:00 | Course: BPC3103 (LECTURE) | Room: C3M05 | Lecturer: DR. MARWAN ABDELMAHMOUD ABDELKARIM MAKI
# 20:00 ~ 21:00 | Course: DBB1014 (TUTORIAL) | Room: MPH - GBS | Lecturer: SR. MARINA HASSAN
# 20:00 ~ 21:00 | Course: FBF1153 (TUTORIAL) | Room: MPH - GBS | Lecturer: SALEH ABDULALEM ALI MOHAMMED
# 20:00 ~ 21:00 | Course: FBF1364 (LECTURE) | Room: None | Lecturer: DR. MARCIA EDNA SANTHANARAJAN
